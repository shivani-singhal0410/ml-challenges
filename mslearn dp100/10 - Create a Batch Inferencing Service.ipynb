# %% [markdown]
# # Create a Batch Inferencing Service
#
# Imagine a health clinic takes patient measurements all day, saving the details for each patient in a separate file. Then overnight, the diabetes prediction model can be used to process all of the day's patient data as a batch, generating predictions that will be waiting the following morning so that the clinic can follow up with patients who are predicted to be at risk of diabetes. With Azure Machine Learning, you can accomplish this by creating a *batch inferencing pipeline*; and that's what you'll implement in this exercise.

# %% [markdown]
# ## Connect to your workspace
#
# To get started, connect to your workspace.
#
# > **Note**: If you haven't already established an authenticated session with your Azure subscription, you'll be prompted to authenticate by clicking a link, entering an authentication code, and signing into Azure.

# %%
import azureml.core
from azureml.core import Workspace

# Load the workspace from the saved config file
ws = Workspace.from_config()
print('Ready to use Azure ML {} to work with {}'.format(azureml.core.VERSION, ws.name))
# Out:
# Ready to use Azure ML 1.40.0 to work with ss_my_aml

# %% [markdown]
# ## Train and register a model
#
# Now let's train and register a model to deploy in a batch inferencing pipeline.

# %%
from azureml.core import Experiment
from azureml.core import Model
import pandas as pd
import numpy as np
import joblib
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

# Create an Azure ML experiment in your workspace
experiment = Experiment(workspace=ws, name='mslearn-train-diabetes')
run = experiment.start_logging()
print("Starting experiment:", experiment.name)

# load the diabetes dataset
print("Loading Data...")
diabetes = pd.read_csv('data/diabetes.csv')

# Separate features and labels
X, y = diabetes[['Pregnancies','PlasmaGlucose','DiastolicBloodPressure','TricepsThickness','SerumInsulin','BMI','DiabetesPedigree','Age']].values, diabetes['Diabetic'].values

# Split data into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=0)

# Train a decision tree model
print('Training a decision tree model')
model = DecisionTreeClassifier().fit(X_train, y_train)

# calculate accuracy
y_hat = model.predict(X_test)
acc = np.average(y_hat == y_test)
print('Accuracy:', acc)
run.log('Accuracy', np.float(acc))

# calculate AUC
y_scores = model.predict_proba(X_test)
auc = roc_auc_score(y_test,y_scores[:,1])
print('AUC: ' + str(auc))
run.log('AUC', np.float(auc))

# Save the trained model
model_file = 'diabetes_model.pkl'
joblib.dump(value=model, filename=model_file)
run.upload_file(name = 'outputs/' + model_file, path_or_stream = './' + model_file)

# Complete the run
run.complete()

# Register the model
run.register_model(model_path='outputs/diabetes_model.pkl', model_name='diabetes_model',
                   tags={'Training context':'Inline Training'},
                   properties={'AUC': run.get_metrics()['AUC'], 'Accuracy': run.get_metrics()['Accuracy']})

print('Model trained and registered.')
# Out:
# Starting experiment: mslearn-train-diabetes
# Loading Data...
# Training a decision tree model
# Accuracy: 0.891
# AUC: 0.8793198666600327
# Model trained and registered.

# %% [markdown]
# ## Generate and upload batch data
#
# Since we don't actually have a fully staffed clinic with patients from whom to get new data for this exercise, you'll generate a random sample from our diabetes CSV file, upload that data to a datastore in the Azure Machine Learning workspace, and register a dataset for it.

# %%
from azureml.core import Datastore, Dataset
import pandas as pd
import os

# Set default data store
ws.set_default_datastore('workspaceblobstore')
default_ds = ws.get_default_datastore()

# Enumerate all datastores, indicating which is the default
for ds_name in ws.datastores:
    print(ds_name, "- Default =", ds_name == default_ds.name)

# Load the diabetes data
diabetes = pd.read_csv('data/diabetes2.csv')
# Get a 100-item sample of the feature columns (not the diabetic label)
sample = diabetes[['Pregnancies','PlasmaGlucose','DiastolicBloodPressure','TricepsThickness','SerumInsulin','BMI','DiabetesPedigree','Age']].sample(n=100).values

# Create a folder
batch_folder = './batch-data'
os.makedirs(batch_folder, exist_ok=True)
print("Folder created!")

# Save each sample as a separate file
print("Saving files...")
for i in range(100):
    fname = str(i+1) + '.csv'
    sample[i].tofile(os.path.join(batch_folder, fname), sep=",")
print("files saved!")

# Upload the files to the default datastore
print("Uploading files to datastore...")
default_ds = ws.get_default_datastore()
default_ds.upload(src_dir="batch-data", target_path="batch-data", overwrite=True, show_progress=True)

# Register a dataset for the input data
batch_data_set = Dataset.File.from_files(path=(default_ds, 'batch-data/'), validate=False)
try:
    batch_data_set = batch_data_set.register(workspace=ws, 
                                             name='batch-data',
                                             description='batch data',
                                             create_new_version=True)
except Exception as ex:
    print(ex)

print("Done!")
# Out:
# azureml_globaldatasets - Default = False
# workspacefilestore - Default = False
# workspaceblobstore - Default = True
# workspaceartifactstore - Default = False
# workspaceworkingdirectory - Default = False
# Folder created!
# Saving files...
# "Datastore.upload" is deprecated after version 1.0.69. Please use "Dataset.File.upload_directory" to upload your files             from a local directory and create FileDataset in single method call. See Dataset API change notice at https://aka.ms/dataset-deprecation.
# files saved!
# Uploading files to datastore...
# Uploading an estimated of 100 files
# Uploading batch-data/1.csv
# Uploaded batch-data/1.csv, 1 files out of an estimated total of 100
# Uploading batch-data/10.csv
# Uploaded batch-data/10.csv, 2 files out of an estimated total of 100
# Uploading batch-data/100.csv
# Uploaded batch-data/100.csv, 3 files out of an estimated total of 100
# Uploading batch-data/11.csv
# Uploaded batch-data/11.csv, 4 files out of an estimated total of 100
# Uploading batch-data/12.csv
# Uploaded batch-data/12.csv, 5 files out of an estimated total of 100
# Uploading batch-data/13.csv
# Uploaded batch-data/13.csv, 6 files out of an estimated total of 100
# Uploading batch-data/14.csv
# Uploaded batch-data/14.csv, 7 files out of an estimated total of 100
# Uploading batch-data/15.csv
# Uploaded batch-data/15.csv, 8 files out of an estimated total of 100
# Uploading batch-data/16.csv
# Uploaded batch-data/16.csv, 9 files out of an estimated total of 100
# Uploading batch-data/17.csv
# Uploaded batch-data/17.csv, 10 files out of an estimated total of 100
# Uploading batch-data/18.csv
# Uploaded batch-data/18.csv, 11 files out of an estimated total of 100
# Uploading batch-data/19.csv
# Uploaded batch-data/19.csv, 12 files out of an estimated total of 100
# Uploading batch-data/2.csv
# Uploaded batch-data/2.csv, 13 files out of an estimated total of 100
# Uploading batch-data/20.csv
# Uploaded batch-data/20.csv, 14 files out of an estimated total of 100
# Uploading batch-data/21.csv
# Uploaded batch-data/21.csv, 15 files out of an estimated total of 100
# Uploading batch-data/22.csv
# Uploaded batch-data/22.csv, 16 files out of an estimated total of 100
# Uploading batch-data/23.csv
# Uploaded batch-data/23.csv, 17 files out of an estimated total of 100
# Uploading batch-data/24.csv
# Uploaded batch-data/24.csv, 18 files out of an estimated total of 100
# Uploading batch-data/25.csv
# Uploaded batch-data/25.csv, 19 files out of an estimated total of 100
# Uploading batch-data/26.csv
# Uploaded batch-data/26.csv, 20 files out of an estimated total of 100
# Uploading batch-data/27.csv
# Uploaded batch-data/27.csv, 21 files out of an estimated total of 100
# Uploading batch-data/28.csv
# Uploaded batch-data/28.csv, 22 files out of an estimated total of 100
# Uploading batch-data/29.csv
# Uploaded batch-data/29.csv, 23 files out of an estimated total of 100
# Uploading batch-data/3.csv
# Uploaded batch-data/3.csv, 24 files out of an estimated total of 100
# Uploading batch-data/30.csv
# Uploaded batch-data/30.csv, 25 files out of an estimated total of 100
# Uploading batch-data/31.csv
# Uploaded batch-data/31.csv, 26 files out of an estimated total of 100
# Uploading batch-data/32.csv
# Uploaded batch-data/32.csv, 27 files out of an estimated total of 100
# Uploading batch-data/33.csv
# Uploaded batch-data/33.csv, 28 files out of an estimated total of 100
# Uploading batch-data/34.csv
# Uploaded batch-data/34.csv, 29 files out of an estimated total of 100
# Uploading batch-data/35.csv
# Uploaded batch-data/35.csv, 30 files out of an estimated total of 100
# Uploading batch-data/36.csv
# Uploaded batch-data/36.csv, 31 files out of an estimated total of 100
# Uploading batch-data/37.csv
# Uploaded batch-data/37.csv, 32 files out of an estimated total of 100
# Uploading batch-data/38.csv
# Uploaded batch-data/38.csv, 33 files out of an estimated total of 100
# Uploading batch-data/39.csv
# Uploaded batch-data/39.csv, 34 files out of an estimated total of 100
# Uploading batch-data/4.csv
# Uploaded batch-data/4.csv, 35 files out of an estimated total of 100
# Uploading batch-data/40.csv
# Uploaded batch-data/40.csv, 36 files out of an estimated total of 100
# Uploading batch-data/41.csv
# Uploaded batch-data/41.csv, 37 files out of an estimated total of 100
# Uploading batch-data/42.csv
# Uploaded batch-data/42.csv, 38 files out of an estimated total of 100
# Uploading batch-data/43.csv
# Uploaded batch-data/43.csv, 39 files out of an estimated total of 100
# Uploading batch-data/44.csv
# Uploaded batch-data/44.csv, 40 files out of an estimated total of 100
# Uploading batch-data/45.csv
# Uploaded batch-data/45.csv, 41 files out of an estimated total of 100
# Uploading batch-data/46.csv
# Uploaded batch-data/46.csv, 42 files out of an estimated total of 100
# Uploading batch-data/47.csv
# Uploaded batch-data/47.csv, 43 files out of an estimated total of 100
# Uploading batch-data/48.csv
# Uploaded batch-data/48.csv, 44 files out of an estimated total of 100
# Uploading batch-data/49.csv
# Uploaded batch-data/49.csv, 45 files out of an estimated total of 100
# Uploading batch-data/5.csv
# Uploaded batch-data/5.csv, 46 files out of an estimated total of 100
# Uploading batch-data/50.csv
# Uploaded batch-data/50.csv, 47 files out of an estimated total of 100
# Uploading batch-data/51.csv
# Uploaded batch-data/51.csv, 48 files out of an estimated total of 100
# Uploading batch-data/52.csv
# Uploaded batch-data/52.csv, 49 files out of an estimated total of 100
# Uploading batch-data/53.csv
# Uploaded batch-data/53.csv, 50 files out of an estimated total of 100
# Uploading batch-data/54.csv
# Uploaded batch-data/54.csv, 51 files out of an estimated total of 100
# Uploading batch-data/55.csv
# Uploaded batch-data/55.csv, 52 files out of an estimated total of 100
# Uploading batch-data/57.csv
# Uploaded batch-data/57.csv, 53 files out of an estimated total of 100
# Uploading batch-data/58.csv
# Uploaded batch-data/58.csv, 54 files out of an estimated total of 100
# Uploading batch-data/59.csv
# Uploaded batch-data/59.csv, 55 files out of an estimated total of 100
# Uploading batch-data/6.csv
# Uploaded batch-data/6.csv, 56 files out of an estimated total of 100
# Uploading batch-data/60.csv
# Uploaded batch-data/60.csv, 57 files out of an estimated total of 100
# Uploading batch-data/61.csv
# Uploaded batch-data/61.csv, 58 files out of an estimated total of 100
# Uploading batch-data/62.csv
# Uploaded batch-data/62.csv, 59 files out of an estimated total of 100
# Uploading batch-data/63.csv
# Uploaded batch-data/63.csv, 60 files out of an estimated total of 100
# Uploading batch-data/64.csv
# Uploaded batch-data/64.csv, 61 files out of an estimated total of 100
# Uploading batch-data/65.csv
# Uploaded batch-data/65.csv, 62 files out of an estimated total of 100
# Uploading batch-data/66.csv
# Uploaded batch-data/66.csv, 63 files out of an estimated total of 100
# Uploading batch-data/67.csv
# Uploaded batch-data/67.csv, 64 files out of an estimated total of 100
# Uploading batch-data/68.csv
# Uploaded batch-data/68.csv, 65 files out of an estimated total of 100
# Uploading batch-data/69.csv
# Uploaded batch-data/69.csv, 66 files out of an estimated total of 100
# Uploading batch-data/7.csv
# Uploaded batch-data/7.csv, 67 files out of an estimated total of 100
# Uploading batch-data/70.csv
# Uploaded batch-data/70.csv, 68 files out of an estimated total of 100
# Uploading batch-data/56.csv
# Uploaded batch-data/56.csv, 69 files out of an estimated total of 100
# Uploading batch-data/71.csv
# Uploaded batch-data/71.csv, 70 files out of an estimated total of 100
# Uploading batch-data/72.csv
# Uploaded batch-data/72.csv, 71 files out of an estimated total of 100
# Uploading batch-data/73.csv
# Uploaded batch-data/73.csv, 72 files out of an estimated total of 100
# Uploading batch-data/74.csv
# Uploaded batch-data/74.csv, 73 files out of an estimated total of 100
# Uploading batch-data/75.csv
# Uploaded batch-data/75.csv, 74 files out of an estimated total of 100
# Uploading batch-data/76.csv
# Uploaded batch-data/76.csv, 75 files out of an estimated total of 100
# Uploading batch-data/77.csv
# Uploaded batch-data/77.csv, 76 files out of an estimated total of 100
# Uploading batch-data/78.csv
# Uploaded batch-data/78.csv, 77 files out of an estimated total of 100
# Uploading batch-data/79.csv
# Uploaded batch-data/79.csv, 78 files out of an estimated total of 100
# Uploading batch-data/8.csv
# Uploaded batch-data/8.csv, 79 files out of an estimated total of 100
# Uploading batch-data/80.csv
# Uploaded batch-data/80.csv, 80 files out of an estimated total of 100
# Uploading batch-data/81.csv
# Uploaded batch-data/81.csv, 81 files out of an estimated total of 100
# Uploading batch-data/82.csv
# Uploaded batch-data/82.csv, 82 files out of an estimated total of 100
# Uploading batch-data/83.csv
# Uploaded batch-data/83.csv, 83 files out of an estimated total of 100
# Uploading batch-data/84.csv
# Uploaded batch-data/84.csv, 84 files out of an estimated total of 100
# Uploading batch-data/85.csv
# Uploaded batch-data/85.csv, 85 files out of an estimated total of 100
# Uploading batch-data/86.csv
# Uploaded batch-data/86.csv, 86 files out of an estimated total of 100
# Uploading batch-data/87.csv
# Uploaded batch-data/87.csv, 87 files out of an estimated total of 100
# Uploading batch-data/88.csv
# Uploaded batch-data/88.csv, 88 files out of an estimated total of 100
# Uploading batch-data/89.csv
# Uploaded batch-data/89.csv, 89 files out of an estimated total of 100
# Uploading batch-data/9.csv
# Uploaded batch-data/9.csv, 90 files out of an estimated total of 100
# Uploading batch-data/90.csv
# Uploaded batch-data/90.csv, 91 files out of an estimated total of 100
# Uploading batch-data/91.csv
# Uploaded batch-data/91.csv, 92 files out of an estimated total of 100
# Uploading batch-data/92.csv
# Uploaded batch-data/92.csv, 93 files out of an estimated total of 100
# Uploading batch-data/93.csv
# Uploaded batch-data/93.csv, 94 files out of an estimated total of 100
# Uploading batch-data/94.csv
# Uploaded batch-data/94.csv, 95 files out of an estimated total of 100
# Uploading batch-data/95.csv
# Uploaded batch-data/95.csv, 96 files out of an estimated total of 100
# Uploading batch-data/96.csv
# Uploaded batch-data/96.csv, 97 files out of an estimated total of 100
# Uploading batch-data/97.csv
# Uploaded batch-data/97.csv, 98 files out of an estimated total of 100
# Uploading batch-data/98.csv
# Uploaded batch-data/98.csv, 99 files out of an estimated total of 100
# Uploading batch-data/99.csv
# Uploaded batch-data/99.csv, 100 files out of an estimated total of 100
# Uploaded 100 files
# Done!

# %% [markdown]
# ## Create compute
#
# We'll need a compute context for the pipeline, so we'll use the following code to specify an Azure Machine Learning compute cluster (it will be created if it doesn't already exist).
#
# > **Important**: Change *your-compute-cluster* to the name of your compute cluster in the code below before running it! Cluster names must be globally unique names between 2 to 16 characters in length. Valid characters are letters, digits, and the - character.

# %%
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException

cluster_name = "your-compute-cluster"

try:
    # Check for existing compute target
    inference_cluster = ComputeTarget(workspace=ws, name=cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    # If it doesn't already exist, create it
    try:
        compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_DS11_V2', max_nodes=2)
        inference_cluster = ComputeTarget.create(ws, cluster_name, compute_config)
        inference_cluster.wait_for_completion(show_output=True)
    except Exception as ex:
        print(ex)
# Out:
# Found existing cluster, use it.

# %% [markdown]
# > **Note**: Compute instances and clusters are based on standard Azure virtual machine images. For this exercise, the *Standard_DS11_v2* image is recommended to achieve the optimal balance of cost and performance. If your subscription has a quota that does not include this image, choose an alternative image; but bear in mind that a larger image may incur higher cost and a smaller image may not be sufficient to complete the tasks. Alternatively, ask your Azure administrator to extend your quota.
#
# ## Create a pipeline for batch inferencing
#
# Now we're ready to define the pipeline we'll use for batch inferencing. Our pipeline will need Python code to perform the batch inferencing, so let's create a folder where we can keep all the files used by the pipeline:

# %%
import os
# Create a folder for the experiment files
experiment_folder = 'batch_pipeline'
os.makedirs(experiment_folder, exist_ok=True)

print(experiment_folder)
# Out:
# batch_pipeline

# %% [markdown]
# Now we'll create a Python script to do the actual work, and save it in the pipeline folder:

# %%
# %%writefile $experiment_folder/batch_diabetes.py
import os
import numpy as np
from azureml.core import Model
import joblib


def init():
    # Runs when the pipeline step is initialized
    global model

    # load the model
    model_path = Model.get_model_path('diabetes_model')
    model = joblib.load(model_path)


def run(mini_batch):
    # This runs for each batch
    resultList = []

    # process each file in the batch
    for f in mini_batch:
        # Read the comma-delimited data into an array
        data = np.genfromtxt(f, delimiter=',')
        # Reshape into a 2-dimensional array for prediction (model expects multiple items)
        prediction = model.predict(data.reshape(1, -1))
        # Append prediction to results
        resultList.append("{}: {}".format(os.path.basename(f), prediction[0]))
    return resultList
# Out:
# Writing batch_pipeline/batch_diabetes.py

# %% [markdown]
# The pipeline will need an environment in which to run, so we'll create a Conda specification that includes the packages that the code uses.

# %%
# %%writefile $experiment_folder/batch_environment.yml
# name: batch_environment
# dependencies:
# - python=3.6.2
# - scikit-learn
# - pip
# - pip:
#   - azureml-defaults
# Out:
# Writing batch_pipeline/batch_environment.yml

# %% [markdown]
# Next we'll define a run context that includes the Conda environment.

# %%
from azureml.core import Environment
from azureml.core.runconfig import DEFAULT_CPU_IMAGE

# Create an Environment for the experiment
batch_env = Environment.from_conda_specification("experiment_env", experiment_folder + "/batch_environment.yml")
batch_env.docker.base_image = DEFAULT_CPU_IMAGE
print('Configuration ready.')
# Out:
# Configuration ready.

# %% [markdown]
# You're going to use a pipeline to run the batch prediction script, generate predictions from the input data, and save the results as a text file in the output folder. To do this, you can use a **ParallelRunStep**, which enables the batch data to be processed in parallel and the results collated in a single output file named *parallel_run_step.txt*.

# %%
from azureml.pipeline.steps import ParallelRunConfig, ParallelRunStep
from azureml.data import OutputFileDatasetConfig

output_dir = OutputFileDatasetConfig(name='inferences')

parallel_run_config = ParallelRunConfig(
    source_directory=experiment_folder,
    entry_script="batch_diabetes.py",
    mini_batch_size="5",
    error_threshold=10,
    output_action="append_row",
    environment=batch_env,
    compute_target=inference_cluster,
    node_count=2)

parallelrun_step = ParallelRunStep(
    name='batch-score-diabetes',
    parallel_run_config=parallel_run_config,
    inputs=[batch_data_set.as_named_input('diabetes_batch')],
    output=output_dir,
    arguments=[],
    allow_reuse=True
)

print('Steps defined')
# Out:
# Steps defined

# %% [markdown]
# Now it's time to put the step into a pipeline, and run it.
#
# > **Note**: This may take some time!

# %%
from azureml.core import Experiment
from azureml.pipeline.core import Pipeline

pipeline = Pipeline(workspace=ws, steps=[parallelrun_step])
pipeline_run = Experiment(ws, 'mslearn-diabetes-batch').submit(pipeline)
pipeline_run.wait_for_completion(show_output=True)
# Out:
# Created step batch-score-diabetes [631217a5][7007b69a-8a94-45d4-bf48-54be8690d630], (This step will run and generate new outputs)
# Submitted PipelineRun 5cfa3dd1-4776-4a3d-b1a9-93020abeacb9
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/5cfa3dd1-4776-4a3d-b1a9-93020abeacb9?wsid=/subscriptions/1e17398b-590b-4bc5-b425-d1e505573710/resourcegroups/ss_my_resgrp/workspaces/ss_my_aml&tid=ae991c30-8b25-49cb-99eb-82160b7acac2
# PipelineRunId: 5cfa3dd1-4776-4a3d-b1a9-93020abeacb9
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/5cfa3dd1-4776-4a3d-b1a9-93020abeacb9?wsid=/subscriptions/1e17398b-590b-4bc5-b425-d1e505573710/resourcegroups/ss_my_resgrp/workspaces/ss_my_aml&tid=ae991c30-8b25-49cb-99eb-82160b7acac2
# PipelineRun Status: Running
#
#
# StepRunId: 9fb10bab-4521-4cae-b106-9fa5fe30aae1
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/9fb10bab-4521-4cae-b106-9fa5fe30aae1?wsid=/subscriptions/1e17398b-590b-4bc5-b425-d1e505573710/resourcegroups/ss_my_resgrp/workspaces/ss_my_aml&tid=ae991c30-8b25-49cb-99eb-82160b7acac2
# StepRun( batch-score-diabetes ) Status: NotStarted
# StepRun( batch-score-diabetes ) Status: Queued
# StepRun( batch-score-diabetes ) Status: Running
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
# 2022/05/05 05:58:13 Downloading source code...
# 2022/05/05 05:58:14 Finished downloading source code
# 2022/05/05 05:58:14 Creating Docker network: acb_default_network, driver: 'bridge'
# 2022/05/05 05:58:14 Successfully set up Docker network: acb_default_network
# 2022/05/05 05:58:14 Setting up Docker configuration...
# 2022/05/05 05:58:15 Successfully set up Docker configuration
# 2022/05/05 05:58:15 Logging in to registry: b81a4c54ff314fccb103c47997228519.azurecr.io
# 2022/05/05 05:58:16 Successfully logged into b81a4c54ff314fccb103c47997228519.azurecr.io
# 2022/05/05 05:58:16 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2022/05/05 05:58:16 Scanning for dependencies...
# 2022/05/05 05:58:17 Successfully scanned dependencies
# 2022/05/05 05:58:17 Launching container with name: acb_step_0
# Sending build context to Docker daemon  66.56kB
#
# Step 1/21 : FROM mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20220314.v1@sha256:7ee68e54cd31cdc4678458ae4a451ed0769828bf439bca5a736777397de4f980
# mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20220314.v1@sha256:7ee68e54cd31cdc4678458ae4a451ed0769828bf439bca5a736777397de4f980: Pulling from azureml/openmpi3.1.2-ubuntu18.04
# cf06a7c31611: Pulling fs layer
# 0159d711301b: Pulling fs layer
# 8b88847355b9: Pulling fs layer
# 509bd2a1e221: Pulling fs layer
# cf0f998fa79d: Pulling fs layer
# 67863f775d4e: Pulling fs layer
# 99cfd53d22e8: Pulling fs layer
# 37392413e856: Pulling fs layer
# b03ca6cd8f42: Pulling fs layer
# 67863f775d4e: Waiting
# 99cfd53d22e8: Waiting
# 37392413e856: Waiting
# b03ca6cd8f42: Waiting
# 509bd2a1e221: Waiting
# cf0f998fa79d: Waiting
# cf06a7c31611: Verifying Checksum
# cf06a7c31611: Download complete
# 8b88847355b9: Verifying Checksum
# 8b88847355b9: Download complete
# 509bd2a1e221: Verifying Checksum
# 509bd2a1e221: Download complete
# 67863f775d4e: Verifying Checksum
# 67863f775d4e: Download complete
# cf0f998fa79d: Verifying Checksum
# cf0f998fa79d: Download complete
# 0159d711301b: Verifying Checksum
# 0159d711301b: Download complete
# 99cfd53d22e8: Verifying Checksum
# 99cfd53d22e8: Download complete
# 37392413e856: Verifying Checksum
# 37392413e856: Download complete
# b03ca6cd8f42: Verifying Checksum
# b03ca6cd8f42: Download complete
# cf06a7c31611: Pull complete
# 0159d711301b: Pull complete
# 8b88847355b9: Pull complete
# 509bd2a1e221: Pull complete
# cf0f998fa79d: Pull complete
# 67863f775d4e: Pull complete
# 99cfd53d22e8: Pull complete
# 37392413e856: Pull complete
# b03ca6cd8f42: Pull complete
# Digest: sha256:7ee68e54cd31cdc4678458ae4a451ed0769828bf439bca5a736777397de4f980
# Status: Downloaded newer image for mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20220314.v1@sha256:7ee68e54cd31cdc4678458ae4a451ed0769828bf439bca5a736777397de4f980
#  ---> 849454c66968
# Step 2/21 : USER root
#  ---> Running in 987a971df78d
# Removing intermediate container 987a971df78d
#  ---> 9fcaffc5fda4
# Step 3/21 : RUN mkdir -p $HOME/.cache
#  ---> Running in 0aad99336ecd
# Removing intermediate container 0aad99336ecd
#  ---> bdbac3cc74ce
# Step 4/21 : WORKDIR /
#  ---> Running in 3fbeeb1d275b
# Removing intermediate container 3fbeeb1d275b
#  ---> 76d179cafb7e
# Step 5/21 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> a6ae70453fd3
# Step 6/21 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in 6271b717df63
# Removing intermediate container 6271b717df63
#  ---> e874239287c0
# Step 7/21 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> 42a38cd384a6
# Step 8/21 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in 69c7ff2087f6
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# Downloading and Extracting Packages
#
# tk-8.6.11            | 3.0 MB    |            |   0%
# tk-8.6.11            | 3.0 MB    | ########## | 100%
# tk-8.6.11            | 3.0 MB    | ########## | 100%
#
# scikit-learn-0.24.2  | 5.2 MB    |            |   0%
# scikit-learn-0.24.2  | 5.2 MB    | ########## | 100%
# scikit-learn-0.24.2  | 5.2 MB    | ########## | 100%
#
# zlib-1.2.12          | 106 KB    |            |   0%
# zlib-1.2.12          | 106 KB    | ########## | 100%
#
# certifi-2021.5.30    | 139 KB    |            |   0%
# certifi-2021.5.30    | 139 KB    | ########## | 100%
#
# libstdcxx-ng-9.3.0   | 3.1 MB    |            |   0%
# libstdcxx-ng-9.3.0   | 3.1 MB    | ########## | 100%
#
# intel-openmp-2022.0. | 4.2 MB    |            |   0%
# intel-openmp-2022.0. | 4.2 MB    | ########## | 100%
# intel-openmp-2022.0. | 4.2 MB    | ########## | 100%
#
# openssl-1.0.2u       | 2.2 MB    |            |   0%
# openssl-1.0.2u       | 2.2 MB    | ########## | 100%
#
# numpy-1.19.2         | 22 KB     |            |   0%
# numpy-1.19.2         | 22 KB     | ########## | 100%
#
# mkl-2020.2           | 138.3 MB  |            |   0%
# mkl-2020.2           | 138.3 MB  | 8          |   9%
# mkl-2020.2           | 138.3 MB  | #7         |  18%
# mkl-2020.2           | 138.3 MB  | ##5        |  26%
# mkl-2020.2           | 138.3 MB  | ###4       |  35%
# mkl-2020.2           | 138.3 MB  | ####2      |  42%
# mkl-2020.2           | 138.3 MB  | ####9      |  49%
# mkl-2020.2           | 138.3 MB  | #####7     |  57%
# mkl-2020.2           | 138.3 MB  | ######4    |  64%
# mkl-2020.2           | 138.3 MB  | #######3   |  74%
# mkl-2020.2           | 138.3 MB  | ########1  |  81%
# mkl-2020.2           | 138.3 MB  | ########8  |  89%
# mkl-2020.2           | 138.3 MB  | #########6 |  96%
# mkl-2020.2           | 138.3 MB  | ########## | 100%
#
# mkl_fft-1.3.0        | 170 KB    |            |   0%
# mkl_fft-1.3.0        | 170 KB    | ########## | 100%
#
# libedit-3.1          | 151 KB    |            |   0%
# libedit-3.1          | 151 KB    | ########## | 100%
#
# ncurses-6.0          | 781 KB    |            |   0%
# ncurses-6.0          | 781 KB    | ########## | 100%
# ncurses-6.0          | 781 KB    | ########## | 100%
#
# libgcc-ng-9.3.0      | 4.8 MB    |            |   0%
# libgcc-ng-9.3.0      | 4.8 MB    | ########## | 100%
# libgcc-ng-9.3.0      | 4.8 MB    | ########## | 100%
#
# scipy-1.5.2          | 14.4 MB   |            |   0%
# scipy-1.5.2          | 14.4 MB   | #######3   |  74%
# scipy-1.5.2          | 14.4 MB   | ########## | 100%
# scipy-1.5.2          | 14.4 MB   | ########## | 100%
#
# libgomp-9.3.0        | 311 KB    |            |   0%
# libgomp-9.3.0        | 311 KB    | ########## | 100%
#
# sqlite-3.23.1        | 808 KB    |            |   0%
# sqlite-3.23.1        | 808 KB    | ########## | 100%
#
# libgfortran4-7.5.0   | 995 KB    |            |   0%
# libgfortran4-7.5.0   | 995 KB    | ########## | 100%
#
# threadpoolctl-2.2.0  | 16 KB     |            |   0%
# threadpoolctl-2.2.0  | 16 KB     | ########## | 100%
#
# joblib-1.0.1         | 208 KB    |            |   0%
# joblib-1.0.1         | 208 KB    | ########## | 100%
#
# mkl_random-1.1.1     | 327 KB    |            |   0%
# mkl_random-1.1.1     | 327 KB    | ########## | 100%
#
# wheel-0.37.1         | 33 KB     |            |   0%
# wheel-0.37.1         | 33 KB     | ########## | 100%
#
# blas-1.0             | 6 KB      |            |   0%
# blas-1.0             | 6 KB      | ########## | 100%
#
# six-1.16.0           | 18 KB     |            |   0%
# six-1.16.0           | 18 KB     | ########## | 100%
#
# libffi-3.2.1         | 48 KB     |            |   0%
# libffi-3.2.1         | 48 KB     | ########## | 100%
#
# setuptools-58.0.4    | 788 KB    |            |   0%
# setuptools-58.0.4    | 788 KB    | ########## | 100%
#
# readline-7.0         | 848 KB    |            |   0%
# readline-7.0         | 848 KB    | ########## | 100%
#
# python-3.6.2         | 23.6 MB   |            |   0%
# python-3.6.2         | 23.6 MB   | ####8      |  49%
# python-3.6.2         | 23.6 MB   | ########## | 100%
# python-3.6.2         | 23.6 MB   | ########## | 100%
#
# mkl-service-2.3.0    | 52 KB     |            |   0%
# mkl-service-2.3.0    | 52 KB     | ########## | 100%
#
# ca-certificates-2022 | 124 KB    |            |   0%
# ca-certificates-2022 | 124 KB    | ########## | 100%
#
# xz-5.2.5             | 339 KB    |            |   0%
# xz-5.2.5             | 339 KB    | ########## | 100%
#
# _openmp_mutex-4.5    | 22 KB     |            |   0%
# _openmp_mutex-4.5    | 22 KB     | ########## | 100%
#
# pip-21.2.2           | 1.8 MB    |            |   0%
# pip-21.2.2           | 1.8 MB    | ########## | 100%
# pip-21.2.2           | 1.8 MB    | ########## | 100%
#
# libgfortran-ng-7.5.0 | 22 KB     |            |   0%
# libgfortran-ng-7.5.0 | 22 KB     | ########## | 100%
#
# numpy-base-1.19.2    | 4.1 MB    |            |   0%
# numpy-base-1.19.2    | 4.1 MB    | ########## | 100%
# numpy-base-1.19.2    | 4.1 MB    | ########## | 100%
#
# _libgcc_mutex-0.1    | 3 KB      |            |   0%
# _libgcc_mutex-0.1    | 3 KB      | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working...
#
#     Installed package of scikit-learn can be accelerated using scikit-learn-intelex.
#     More details are available here: https://intel.github.io/scikit-learn-intelex
#
#     For example:
#
#         $ conda install scikit-learn-intelex
#         $ python -m sklearnex my_application.py
#
#
#
# done
# Installing pip dependencies: ...working...
# Ran pip subprocess with arguments:
# ['/azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d/bin/python', '-m', 'pip', 'install', '-U', '-r', '/azureml-environment-setup/condaenv.ezzzf93q.requirements.txt']
# Pip subprocess output:
# Collecting azureml-defaults
#   Downloading azureml_defaults-1.41.0-py3-none-any.whl (3.0 kB)
# Collecting json-logging-py==0.2
#   Downloading json-logging-py-0.2.tar.gz (3.6 kB)
# Collecting azureml-dataset-runtime[fuse]~=1.41.0
#   Downloading azureml_dataset_runtime-1.41.0-py3-none-any.whl (3.5 kB)
# Collecting configparser==3.7.4
#   Downloading configparser-3.7.4-py2.py3-none-any.whl (22 kB)
# Collecting azureml-inference-server-http~=0.4.1
#   Downloading azureml_inference_server_http-0.4.13-py3-none-any.whl (39 kB)
# Collecting azureml-core~=1.41.0
#   Downloading azureml_core-1.41.0.post1-py3-none-any.whl (2.7 MB)
# Collecting msrestazure<=0.6.4,>=0.4.33
#   Downloading msrestazure-0.6.4-py2.py3-none-any.whl (40 kB)
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<37.0.0
#   Downloading cryptography-36.0.2-cp36-abi3-manylinux_2_24_x86_64.whl (3.6 MB)
# Collecting adal<=1.2.7,>=1.2.0
#   Downloading adal-1.2.7-py2.py3-none-any.whl (55 kB)
# Collecting msal-extensions<0.4,>=0.3.0
#   Downloading msal_extensions-0.3.1-py2.py3-none-any.whl (18 kB)
# Collecting paramiko<3.0.0,>=2.0.8
#   Downloading paramiko-2.10.4-py2.py3-none-any.whl (212 kB)
# Collecting azure-mgmt-authorization<3,>=0.40.0
#   Downloading azure_mgmt_authorization-2.0.0-py2.py3-none-any.whl (465 kB)
# Collecting pyopenssl<23.0.0
#   Downloading pyOpenSSL-22.0.0-py2.py3-none-any.whl (55 kB)
# Collecting humanfriendly<11.0,>=4.7
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Collecting azure-mgmt-containerregistry<10,>=8.2.0
#   Downloading azure_mgmt_containerregistry-9.1.0-py3-none-any.whl (1.1 MB)
# Collecting jsonpickle<3.0.0
#   Downloading jsonpickle-2.1.0-py2.py3-none-any.whl (38 kB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting pathspec<1.0.0
#   Downloading pathspec-0.9.0-py2.py3-none-any.whl (31 kB)
# Collecting python-dateutil<3.0.0,>=2.7.3
#   Downloading python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
# Collecting docker<6.0.0
#   Downloading docker-5.0.3-py2.py3-none-any.whl (146 kB)
# Collecting knack~=0.9.0
#   Downloading knack-0.9.0-py3-none-any.whl (59 kB)
# Collecting azure-mgmt-keyvault<10.0.0,>=0.40.0
#   Downloading azure_mgmt_keyvault-9.3.0-py2.py3-none-any.whl (412 kB)
# Collecting PyJWT<3.0.0
#   Downloading PyJWT-2.3.0-py3-none-any.whl (16 kB)
# Collecting azure-mgmt-storage<20.0.0,>=16.0.0
#   Downloading azure_mgmt_storage-19.1.0-py3-none-any.whl (1.8 MB)
# Collecting azure-common<2.0.0,>=1.1.12
#   Downloading azure_common-1.1.28-py2.py3-none-any.whl (14 kB)
# Collecting pytz
#   Downloading pytz-2022.1-py2.py3-none-any.whl (503 kB)
# Collecting urllib3<=1.26.7,>=1.23
#   Downloading urllib3-1.26.7-py2.py3-none-any.whl (138 kB)
# Collecting contextlib2<22.0.0
#   Downloading contextlib2-21.6.0-py2.py3-none-any.whl (13 kB)
# Collecting packaging<22.0,>=20.0
#   Downloading packaging-21.3-py3-none-any.whl (40 kB)
# Collecting azure-core<2.0.0
#   Downloading azure_core-1.23.1-py3-none-any.whl (178 kB)
# Collecting azure-graphrbac<1.0.0,>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting azure-mgmt-resource<21.0.0,>=15.0.0
#   Downloading azure_mgmt_resource-20.1.0-py3-none-any.whl (2.3 MB)
# Collecting jmespath<1.0.0
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting requests[socks]<3.0.0,>=2.19.1
#   Downloading requests-2.27.1-py2.py3-none-any.whl (63 kB)
# Collecting pkginfo
#   Downloading pkginfo-1.8.2-py2.py3-none-any.whl (26 kB)
# Collecting msal<2.0.0,>=1.15.0
#   Downloading msal-1.17.0-py2.py3-none-any.whl (79 kB)
# Collecting SecretStorage<4.0.0
#   Downloading SecretStorage-3.3.2-py3-none-any.whl (15 kB)
# Collecting ndg-httpsclient<=0.5.1
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting argcomplete<3
#   Downloading argcomplete-2.0.0-py2.py3-none-any.whl (37 kB)
# Collecting msrest<1.0.0,>=0.5.1
#   Downloading msrest-0.6.21-py2.py3-none-any.whl (85 kB)
# Collecting importlib-metadata<5,>=0.23
#   Downloading importlib_metadata-4.8.3-py3-none-any.whl (17 kB)
# Requirement already satisfied: six>=1.11.0 in /azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d/lib/python3.6/site-packages (from azure-core<2.0.0->azureml-core~=1.41.0->azureml-defaults->-r /azureml-environment-setup/condaenv.ezzzf93q.requirements.txt (line 1)) (1.16.0)
# Collecting typing-extensions>=4.0.1
#   Downloading typing_extensions-4.1.1-py3-none-any.whl (26 kB)
# Collecting azure-mgmt-core<2.0.0,>=1.2.0
#   Downloading azure_mgmt_core-1.3.0-py2.py3-none-any.whl (25 kB)
# Collecting azureml-dataprep<3.2.0a,>=3.1.0a
#   Downloading azureml_dataprep-3.1.2-py3-none-any.whl (38.6 MB)
# Collecting pyarrow<4.0.0,>=0.17.0
#   Downloading pyarrow-3.0.0-cp36-cp36m-manylinux2014_x86_64.whl (20.7 MB)
# Requirement already satisfied: numpy!=1.19.3 in /azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d/lib/python3.6/site-packages (from azureml-dataset-runtime[fuse]~=1.41.0->azureml-defaults->-r /azureml-environment-setup/condaenv.ezzzf93q.requirements.txt (line 1)) (1.19.2)
# Collecting fusepy<4.0.0,>=3.0.1
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
# Collecting dotnetcore2<3.0.0,>=2.1.14
#   Downloading dotnetcore2-2.1.23-py3-none-manylinux1_x86_64.whl (29.3 MB)
# Collecting azureml-dataprep-native<39.0.0,>=38.0.0
#   Downloading azureml_dataprep_native-38.0.0-cp36-cp36m-manylinux1_x86_64.whl (1.3 MB)
# Collecting azureml-dataprep-rslex~=2.5.0dev0
#   Downloading azureml_dataprep_rslex-2.5.3-cp36-cp36m-manylinux1_x86_64.whl (15.5 MB)
# Collecting azure-identity==1.7.0
#   Downloading azure_identity-1.7.0-py2.py3-none-any.whl (129 kB)
# Collecting cloudpickle<3.0.0,>=1.1.0
#   Downloading cloudpickle-2.0.0-py3-none-any.whl (25 kB)
# Collecting flask==1.0.3
#   Downloading Flask-1.0.3-py2.py3-none-any.whl (92 kB)
# Collecting click<8.0,>=5.1
#   Downloading click-7.1.2-py2.py3-none-any.whl (82 kB)
# Collecting inference-schema==1.3.0
#   Downloading inference_schema-1.3.0-py3-none-any.whl (19 kB)
# Collecting opencensus-ext-azure~=1.1.0
#   Downloading opencensus_ext_azure-1.1.4-py2.py3-none-any.whl (40 kB)
# Collecting itsdangerous<2.0,>=0.24
#   Downloading itsdangerous-1.1.0-py2.py3-none-any.whl (16 kB)
# Collecting Jinja2<3.1,>=2.10.1
#   Downloading Jinja2-3.0.3-py3-none-any.whl (133 kB)
# Collecting applicationinsights>=0.11.7
#   Downloading applicationinsights-0.11.10-py2.py3-none-any.whl (55 kB)
# Collecting Werkzeug<2.0,>=0.15
#   Downloading Werkzeug-1.0.1-py2.py3-none-any.whl (298 kB)
# Collecting gunicorn==20.1.0
#   Downloading gunicorn-20.1.0-py3-none-any.whl (79 kB)
# Requirement already satisfied: setuptools>=3.0 in /azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d/lib/python3.6/site-packages (from gunicorn==20.1.0->azureml-inference-server-http~=0.4.1->azureml-defaults->-r /azureml-environment-setup/condaenv.ezzzf93q.requirements.txt (line 1)) (58.0.4)
# Collecting wrapt<=1.12.1,>=1.11.1
#   Downloading wrapt-1.12.1.tar.gz (27 kB)
# Collecting cffi>=1.12
#   Downloading cffi-1.15.0-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (405 kB)
# Collecting pycparser
#   Downloading pycparser-2.21-py2.py3-none-any.whl (118 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-1.3.1-py3-none-any.whl (54 kB)
# Collecting distro>=1.2.0
#   Downloading distro-1.7.0-py3-none-any.whl (20 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.6.0-py3-none-any.whl (5.3 kB)
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-2.0.1-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (30 kB)
# Collecting pygments
#   Downloading Pygments-2.12.0-py3-none-any.whl (1.1 MB)
# Collecting pyyaml
#   Downloading PyYAML-6.0-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (603 kB)
# Collecting tabulate
#   Downloading tabulate-0.8.9-py3-none-any.whl (25 kB)
# Collecting portalocker<3,>=1.0
#   Downloading portalocker-2.4.0-py2.py3-none-any.whl (16 kB)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d/lib/python3.6/site-packages (from msrest<1.0.0,>=0.5.1->azureml-core~=1.41.0->azureml-defaults->-r /azureml-environment-setup/condaenv.ezzzf93q.requirements.txt (line 1)) (2021.5.30)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting psutil>=5.6.3
#   Downloading psutil-5.9.0-cp36-cp36m-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (279 kB)
# Collecting opencensus<1.0.0,>=0.8.0
#   Downloading opencensus-0.9.0-py2.py3-none-any.whl (128 kB)
# Collecting google-api-core<3.0.0,>=1.0.0
#   Downloading google_api_core-2.7.3-py3-none-any.whl (114 kB)
# Collecting opencensus-context>=0.1.2
#   Downloading opencensus_context-0.1.2-py2.py3-none-any.whl (4.4 kB)
# Collecting protobuf>=3.12.0
#   Downloading protobuf-3.19.4-cp36-cp36m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
# Collecting google-auth<3.0dev,>=1.25.0
#   Downloading google_auth-2.6.6-py2.py3-none-any.whl (156 kB)
# Collecting googleapis-common-protos<2.0dev,>=1.52.0
#   Downloading googleapis_common_protos-1.56.0-py2.py3-none-any.whl (241 kB)
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.8-py3-none-any.whl (39 kB)
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-4.2.4-py3-none-any.whl (10 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting contextvars
#   Downloading contextvars-2.4.tar.gz (9.6 kB)
# Collecting pyparsing!=3.0.5,>=2.0.2
#   Downloading pyparsing-3.0.7-py3-none-any.whl (98 kB)
# Collecting bcrypt>=3.1.3
#   Downloading bcrypt-3.2.2-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (62 kB)
# Collecting pynacl>=1.0.1
#   Downloading PyNaCl-1.5.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (856 kB)
# Collecting charset-normalizer~=2.0.0
#   Downloading charset_normalizer-2.0.12-py3-none-any.whl (39 kB)
# Collecting idna<4,>=2.5
#   Downloading idna-3.3-py3-none-any.whl (61 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.0-py3-none-any.whl (151 kB)
# Collecting PySocks!=1.5.7,>=1.5.6
#   Downloading PySocks-1.7.1-py3-none-any.whl (16 kB)
# Collecting jeepney>=0.6
#   Downloading jeepney-0.7.1-py3-none-any.whl (54 kB)
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Collecting immutables>=0.9
#   Downloading immutables-0.17-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (115 kB)
# Building wheels for collected packages: json-logging-py, fusepy, wrapt, contextvars
#   Building wheel for json-logging-py (setup.py): started
#   Building wheel for json-logging-py (setup.py): finished with status 'done'
#   Created wheel for json-logging-py: filename=json_logging_py-0.2-py3-none-any.whl size=3924 sha256=8f99d6d50ce965bcad7c5a6ccf232c69ec8de1c2e5f7946e2323de0d73c51774
#   Stored in directory: /root/.cache/pip/wheels/e2/1d/52/535a274b9c2ce7d4064838f2bdb62013801281ef7d7f21e2ee
#   Building wheel for fusepy (setup.py): started
#   Building wheel for fusepy (setup.py): finished with status 'done'
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10503 sha256=8ed286fc2e364f5399ea87cfd6f70ce9d5c8f12ba057b015cc5dc45d78605467
#   Stored in directory: /root/.cache/pip/wheels/21/5c/83/1dd7e8a232d12227e5410120f4374b33adeb4037473105b079
#   Building wheel for wrapt (setup.py): started
#   Building wheel for wrapt (setup.py): finished with status 'done'
#   Created wheel for wrapt: filename=wrapt-1.12.1-cp36-cp36m-linux_x86_64.whl size=69935 sha256=0a083c31769a341abda66c7fd6b7a8f9fadbaf72b80d10f118600c2acfe90b6a
#   Stored in directory: /root/.cache/pip/wheels/32/42/7f/23cae9ff6ef66798d00dc5d659088e57dbba01566f6c60db63
#   Building wheel for contextvars (setup.py): started
#   Building wheel for contextvars (setup.py): finished with status 'done'
#   Created wheel for contextvars: filename=contextvars-2.4-py3-none-any.whl size=7681 sha256=2fc187cd8c590a12b272e6e1219922eb9120b0d37564320b5c792b769b835b9d
#   Stored in directory: /root/.cache/pip/wheels/41/11/53/911724983aa48deb94792432e14e518447212dd6c5477d49d3
# Successfully built json-logging-py fusepy wrapt contextvars
# Installing collected packages: pycparser, cffi, urllib3, PyJWT, idna, cryptography, charset-normalizer, typing-extensions, requests, pyasn1, rsa, pyasn1-modules, protobuf, portalocker, oauthlib, msal, immutables, cachetools, zipp, requests-oauthlib, python-dateutil, msal-extensions, isodate, googleapis-common-protos, google-auth, distro, contextvars, azure-core, opencensus-context, msrest, MarkupSafe, importlib-metadata, google-api-core, dotnetcore2, cloudpickle, azureml-dataprep-rslex, azureml-dataprep-native, azure-identity, adal, wrapt, Werkzeug, websocket-client, tabulate, pyyaml, pytz, PySocks, pyparsing, pyopenssl, pynacl, pygments, pyarrow, psutil, opencensus, msrestazure, jmespath, Jinja2, jeepney, itsdangerous, click, bcrypt, backports.weakref, azureml-dataprep, azure-mgmt-core, azure-common, argcomplete, SecretStorage, pkginfo, pathspec, paramiko, packaging, opencensus-ext-azure, ndg-httpsclient, knack, jsonpickle, inference-schema, humanfriendly, gunicorn, fusepy, flask, docker, contextlib2, backports.tempfile, azureml-dataset-runtime, azure-mgmt-storage, azure-mgmt-resource, azure-mgmt-keyvault, azure-mgmt-containerregistry, azure-mgmt-authorization, azure-graphrbac, applicationinsights, json-logging-py, configparser, azureml-inference-server-http, azureml-core, azureml-defaults
# Successfully installed Jinja2-3.0.3 MarkupSafe-2.0.1 PyJWT-2.3.0 PySocks-1.7.1 SecretStorage-3.3.2 Werkzeug-1.0.1 adal-1.2.7 applicationinsights-0.11.10 argcomplete-2.0.0 azure-common-1.1.28 azure-core-1.23.1 azure-graphrbac-0.61.1 azure-identity-1.7.0 azure-mgmt-authorization-2.0.0 azure-mgmt-containerregistry-9.1.0 azure-mgmt-core-1.3.0 azure-mgmt-keyvault-9.3.0 azure-mgmt-resource-20.1.0 azure-mgmt-storage-19.1.0 azureml-core-1.41.0.post1 azureml-dataprep-3.1.2 azureml-dataprep-native-38.0.0 azureml-dataprep-rslex-2.5.3 azureml-dataset-runtime-1.41.0 azureml-defaults-1.41.0 azureml-inference-server-http-0.4.13 backports.tempfile-1.0 backports.weakref-1.0.post1 bcrypt-3.2.2 cachetools-4.2.4 cffi-1.15.0 charset-normalizer-2.0.12 click-7.1.2 cloudpickle-2.0.0 configparser-3.7.4 contextlib2-21.6.0 contextvars-2.4 cryptography-36.0.2 distro-1.7.0 docker-5.0.3 dotnetcore2-2.1.23 flask-1.0.3 fusepy-3.0.1 google-api-core-2.7.3 google-auth-2.6.6 googleapis-common-protos-1.56.0 gunicorn-20.1.0 humanfriendly-10.0 idna-3.3 immutables-0.17 importlib-metadata-4.8.3 inference-schema-1.3.0 isodate-0.6.1 itsdangerous-1.1.0 jeepney-0.7.1 jmespath-0.10.0 json-logging-py-0.2 jsonpickle-2.1.0 knack-0.9.0 msal-1.17.0 msal-extensions-0.3.1 msrest-0.6.21 msrestazure-0.6.4 ndg-httpsclient-0.5.1 oauthlib-3.2.0 opencensus-0.9.0 opencensus-context-0.1.2 opencensus-ext-azure-1.1.4 packaging-21.3 paramiko-2.10.4 pathspec-0.9.0 pkginfo-1.8.2 portalocker-2.4.0 protobuf-3.19.4 psutil-5.9.0 pyarrow-3.0.0 pyasn1-0.4.8 pyasn1-modules-0.2.8 pycparser-2.21 pygments-2.12.0 pynacl-1.5.0 pyopenssl-22.0.0 pyparsing-3.0.7 python-dateutil-2.8.2 pytz-2022.1 pyyaml-6.0 requests-2.27.1 requests-oauthlib-1.3.1 rsa-4.8 tabulate-0.8.9 typing-extensions-4.1.1 urllib3-1.26.7 websocket-client-1.3.1 wrapt-1.12.1 zipp-3.6.0
#
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate /azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.2
#   latest version: 4.12.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
# WARNING: /root/.conda/pkgs does not exist
# Removing intermediate container 69c7ff2087f6
#  ---> 6df5b821c72b
# Step 9/21 : ENV PATH /azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d/bin:$PATH
#  ---> Running in 270918f1a5c3
# Removing intermediate container 270918f1a5c3
#  ---> 8527be86731b
# Step 10/21 : COPY azureml-environment-setup/send_conda_dependencies.py azureml-environment-setup/send_conda_dependencies.py
#  ---> 216a43253683
# Step 11/21 : RUN echo "Copying environment context"
#  ---> Running in 5bfabb4719db
# Copying environment context
# Removing intermediate container 5bfabb4719db
#  ---> 4b5c1dfedba7
# Step 12/21 : COPY azureml-environment-setup/environment_context.json azureml-environment-setup/environment_context.json
#  ---> 9ae74b61ec4e
# Step 13/21 : RUN python /azureml-environment-setup/send_conda_dependencies.py -p /azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d
#  ---> Running in 4bbcd3475d66
# Report materialized dependencies for the environment
# Reading environment context
# Exporting conda environment
# Sending request with materialized conda environment details
# Successfully sent materialized environment details
# Removing intermediate container 4bbcd3475d66
#  ---> 307127fe60fb
# Step 14/21 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d
#  ---> Running in 012c28714396
# Removing intermediate container 012c28714396
#  ---> c486cb24dee4
# Step 15/21 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d/lib:$LD_LIBRARY_PATH
#  ---> Running in 0b400ecc568c
# Removing intermediate container 0b400ecc568c
#  ---> 59866b4923fd
# Step 16/21 : ENV CONDA_DEFAULT_ENV=azureml_e220b045f6c3c3008b1a386af067185d CONDA_PREFIX=/azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d
#  ---> Running in 036935bbd1c4
# Removing intermediate container 036935bbd1c4
#  ---> 32030279a501
# Step 17/21 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> 979a15f6ba61
# Step 18/21 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit  /azureml-environment-setup/spark_cache.py'; fi
#  ---> Running in 7c5166bb7480
# Removing intermediate container 7c5166bb7480
#  ---> f014f8bfba81
# Step 19/21 : RUN rm -rf azureml-environment-setup
#  ---> Running in c85da6de0f5a
# Removing intermediate container c85da6de0f5a
#  ---> 348c427cf4e2
# Step 20/21 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in 508e7a690672
# Removing intermediate container 508e7a690672
#  ---> c94aca91b6b6
# Step 21/21 : CMD ["bash"]
#  ---> Running in 399a0f630e38
# Removing intermediate container 399a0f630e38
#  ---> f88fb2d65c4d
# Successfully built f88fb2d65c4d
# Successfully tagged b81a4c54ff314fccb103c47997228519.azurecr.io/azureml/azureml_238fef72f720d284a2e68cccbc4ded74:latest
# Successfully tagged b81a4c54ff314fccb103c47997228519.azurecr.io/azureml/azureml_238fef72f720d284a2e68cccbc4ded74:1
# 2022/05/05 06:00:08 Successfully executed container: acb_step_0
# 2022/05/05 06:00:08 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2022/05/05 06:00:08 Pushing image: b81a4c54ff314fccb103c47997228519.azurecr.io/azureml/azureml_238fef72f720d284a2e68cccbc4ded74:1, attempt 1
# The push refers to repository [b81a4c54ff314fccb103c47997228519.azurecr.io/azureml/azureml_238fef72f720d284a2e68cccbc4ded74]
# de340416e17c: Preparing
# ab6822c941c9: Preparing
# 017caf39a8c4: Preparing
# bdae6f3eb78f: Preparing
# 90f945bea1f5: Preparing
# 9bf539772ce4: Preparing
# 15eba97a0f56: Preparing
# f98db56a651a: Preparing
# da1652a3b353: Preparing
# 52d40a4669ed: Preparing
# 152ab1cf0506: Preparing
# 2a8c27ecc2d4: Preparing
# c289ce712c06: Preparing
# ed535c57edb5: Preparing
# d402679c3e9d: Preparing
# 02b786e5916e: Preparing
# 04c54c9cadfd: Preparing
# e83750761fa5: Preparing
# a4e25480be6b: Preparing
# 9bf539772ce4: Waiting
# 15eba97a0f56: Waiting
# f98db56a651a: Waiting
# da1652a3b353: Waiting
# 52d40a4669ed: Waiting
# 152ab1cf0506: Waiting
# 2a8c27ecc2d4: Waiting
# c289ce712c06: Waiting
# ed535c57edb5: Waiting
# d402679c3e9d: Waiting
# 02b786e5916e: Waiting
# 04c54c9cadfd: Waiting
# e83750761fa5: Waiting
# a4e25480be6b: Waiting
# de340416e17c: Pushed
# 90f945bea1f5: Pushed
# ab6822c941c9: Pushed
# 017caf39a8c4: Pushed
# 15eba97a0f56: Pushed
# da1652a3b353: Pushed
# f98db56a651a: Pushed
# 52d40a4669ed: Pushed
# 2a8c27ecc2d4: Pushed
# bdae6f3eb78f: Pushed
# 152ab1cf0506: Pushed
# c289ce712c06: Pushed
# 02b786e5916e: Pushed
# ed535c57edb5: Pushed
# 04c54c9cadfd: Pushed
#
# a4e25480be6b: Pushed
# d402679c3e9d: Pushed
# e83750761fa5: Pushed
# 9bf539772ce4: Pushed
# 1: digest: sha256:a00b83e5bdc51915c79f5aa43b26728ebf5040346b6b465708eaffd5dc66fa91 size: 4306
# 2022/05/05 06:01:41 Successfully pushed image: b81a4c54ff314fccb103c47997228519.azurecr.io/azureml/azureml_238fef72f720d284a2e68cccbc4ded74:1
# 2022/05/05 06:01:41 Executing step ID: acb_step_2. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2022/05/05 06:01:41 Pushing image: b81a4c54ff314fccb103c47997228519.azurecr.io/azureml/azureml_238fef72f720d284a2e68cccbc4ded74:latest, attempt 1
# The push refers to repository [b81a4c54ff314fccb103c47997228519.azurecr.io/azureml/azureml_238fef72f720d284a2e68cccbc4ded74]
# de340416e17c: Preparing
# ab6822c941c9: Preparing
# 017caf39a8c4: Preparing
# bdae6f3eb78f: Preparing
# 90f945bea1f5: Preparing
# 9bf539772ce4: Preparing
# 15eba97a0f56: Preparing
# f98db56a651a: Preparing
# da1652a3b353: Preparing
# 52d40a4669ed: Preparing
# 152ab1cf0506: Preparing
# 2a8c27ecc2d4: Preparing
# c289ce712c06: Preparing
# ed535c57edb5: Preparing
# d402679c3e9d: Preparing
# 02b786e5916e: Preparing
# 04c54c9cadfd: Preparing
# e83750761fa5: Preparing
# a4e25480be6b: Preparing
# 9bf539772ce4: Waiting
# 15eba97a0f56: Waiting
# f98db56a651a: Waiting
# da1652a3b353: Waiting
# 52d40a4669ed: Waiting
# 152ab1cf0506: Waiting
# 2a8c27ecc2d4: Waiting
# c289ce712c06: Waiting
# ed535c57edb5: Waiting
# d402679c3e9d: Waiting
# 02b786e5916e: Waiting
# 04c54c9cadfd: Waiting
# e83750761fa5: Waiting
# a4e25480be6b: Waiting
# 90f945bea1f5: Layer already exists
# 9bf539772ce4: Layer already exists
# 15eba97a0f56: Layer already exists
# f98db56a651a: Layer already exists
# da1652a3b353: Layer already exists
# 52d40a4669ed: Layer already exists
# 152ab1cf0506: Layer already exists
# 2a8c27ecc2d4: Layer already exists
# c289ce712c06: Layer already exists
# ed535c57edb5: Layer already exists
# d402679c3e9d: Layer already exists
# 02b786e5916e: Layer already exists
# 04c54c9cadfd: Layer already exists
# e83750761fa5: Layer already exists
# bdae6f3eb78f: Layer already exists
# 017caf39a8c4: Layer already exists
# de340416e17c: Layer already exists
# a4e25480be6b: Layer already exists
# ab6822c941c9: Layer already exists
# latest: digest: sha256:a00b83e5bdc51915c79f5aa43b26728ebf5040346b6b465708eaffd5dc66fa91 size: 4306
# 2022/05/05 06:01:43 Successfully pushed image: b81a4c54ff314fccb103c47997228519.azurecr.io/azureml/azureml_238fef72f720d284a2e68cccbc4ded74:latest
# 2022/05/05 06:01:43 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 112.085292)
# 2022/05/05 06:01:43 Populating digests for step ID: acb_step_0...
# 2022/05/05 06:01:45 Successfully populated digests for step ID: acb_step_0
# 2022/05/05 06:01:45 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 92.703013)
# 2022/05/05 06:01:45 Step ID: acb_step_2 marked as successful (elapsed time in seconds: 2.459949)
# 2022/05/05 06:01:45 The following dependencies were found:
# 2022/05/05 06:01:45
# - image:
#     registry: b81a4c54ff314fccb103c47997228519.azurecr.io
#     repository: azureml/azureml_238fef72f720d284a2e68cccbc4ded74
#     tag: latest
#     digest: sha256:a00b83e5bdc51915c79f5aa43b26728ebf5040346b6b465708eaffd5dc66fa91
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/openmpi3.1.2-ubuntu18.04
#     tag: 20220314.v1
#     digest: sha256:7ee68e54cd31cdc4678458ae4a451ed0769828bf439bca5a736777397de4f980
#   git: {}
# - image:
#     registry: b81a4c54ff314fccb103c47997228519.azurecr.io
#     repository: azureml/azureml_238fef72f720d284a2e68cccbc4ded74
#     tag: "1"
#     digest: sha256:a00b83e5bdc51915c79f5aa43b26728ebf5040346b6b465708eaffd5dc66fa91
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/openmpi3.1.2-ubuntu18.04
#     tag: 20220314.v1
#     digest: sha256:7ee68e54cd31cdc4678458ae4a451ed0769828bf439bca5a736777397de4f980
#   git: {}
#
# Run ID: cr3 was successful after 3m32s
#
# Streaming azureml-logs/55_azureml-execution-tvmps_b9b383c961b9e9d38714d5ce559d014e3166b2fff5a40fbc49b91e43998007a4_d.txt
# ========================================================================================================================
# 2022-05-05T06:09:36Z Running following command: /bin/bash -c sudo blobfuse /mnt/batch/tasks/shared/LS_root/jobs/ss_my_aml/azureml/9fb10bab-4521-4cae-b106-9fa5fe30aae1/mounts/workspaceblobstore --tmp-path=/mnt/batch/tasks/shared/LS_root/jobs/ss_my_aml/azureml/9fb10bab-4521-4cae-b106-9fa5fe30aae1/caches/workspaceblobstore -o ro --file-cache-timeout-in-seconds=1000000 --cache-size-mb=24620 -o nonempty -o allow_other --config-file=/mnt/batch/tasks/shared/LS_root/jobs/ss_my_aml/azureml/9fb10bab-4521-4cae-b106-9fa5fe30aae1/configs/workspaceblobstore.cfg --log-level=LOG_WARNING
# 2022-05-05T06:09:36Z Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/ss_my_aml/azureml/9fb10bab-4521-4cae-b106-9fa5fe30aae1/mounts/workspaceblobstore -- stdout/stderr:
# 2022-05-05T06:09:37Z The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2022-05-05T06:09:37Z Starting output-watcher...
# 2022-05-05T06:09:37Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 2022-05-05T06:09:37Z Executing 'Copy ACR Details file' on 10.0.0.7
# 2022-05-05T06:09:37Z Executing 'Copy ACR Details file' on 10.0.0.4
# 2022-05-05T06:09:37Z Copy ACR Details file succeeded on 10.0.0.4. Output:
# >>>
# >>>
# 2022-05-05T06:09:38Z Copy ACR Details file succeeded on 10.0.0.7. Output:
# >>>
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_23e1bb4ca54a555eb02ea38dd537c165
# 92473f7ef455: Pulling fs layer
# fb52bde70123: Pulling fs layer
# 64788f86be3f: Pulling fs layer
# 33f6d5f2e001: Pulling fs layer
# eeb715f1b6ae: Pulling fs layer
# fe519cf36537: Pulling fs layer
# 58ff99196c15: Pulling fs layer
# 9b13f06a8eff: Pulling fs layer
# 2d4e93adbf58: Pulling fs layer
# 6ee7c3767844: Pulling fs layer
# 62cfc3ccb8ab: Pulling fs layer
# 4a7af9d757ee: Pulling fs layer
# 87befe721bae: Pulling fs layer
# 88ebf812112d: Pulling fs layer
# 6aec08a9bbdc: Pulling fs layer
# 7ab4917d9fd7: Pulling fs layer
# 0509d37259e1: Pulling fs layer
# a9fe999b238c: Pulling fs layer
# de332e6a4d0f: Pulling fs layer
# 948484c8c953: Pulling fs layer
# 69b601b6c28f: Pulling fs layer
# 576d2fdf95bc: Pulling fs layer
# 4a7af9d757ee: Waiting
# 87befe721bae: Waiting
# 88ebf812112d: Waiting
# 6aec08a9bbdc: Waiting
# 7ab4917d9fd7: Waiting
# 0509d37259e1: Waiting
# a9fe999b238c: Waiting
# de332e6a4d0f: Waiting
# 948484c8c953: Waiting
# 69b601b6c28f: Waiting
# 576d2fdf95bc: Waiting
# 33f6d5f2e001: Waiting
# eeb715f1b6ae: Waiting
# fe519cf36537: Waiting
# 2d4e93adbf58: Waiting
# 58ff99196c15: Waiting
# 9b13f06a8eff: Waiting
# 6ee7c3767844: Waiting
# 62cfc3ccb8ab: Waiting
# fb52bde70123: Verifying Checksum
# fb52bde70123: Download complete
# 64788f86be3f: Verifying Checksum
# 64788f86be3f: Download complete
# 33f6d5f2e001: Verifying Checksum
# 33f6d5f2e001: Download complete
# 92473f7ef455: Verifying Checksum
# 92473f7ef455: Download complete
#
# Streaming azureml-logs/55_azureml-execution-tvmps_03e8fd70f5a489120a451b3f271e284563569639c0d6e7acc5f801b7abce8bef_d.txt
# ========================================================================================================================
# 2022-05-05T06:09:36Z Running following command: /bin/bash -c sudo blobfuse /mnt/batch/tasks/shared/LS_root/jobs/ss_my_aml/azureml/9fb10bab-4521-4cae-b106-9fa5fe30aae1/mounts/workspaceblobstore --tmp-path=/mnt/batch/tasks/shared/LS_root/jobs/ss_my_aml/azureml/9fb10bab-4521-4cae-b106-9fa5fe30aae1/caches/workspaceblobstore -o ro --file-cache-timeout-in-seconds=1000000 --cache-size-mb=24620 -o nonempty -o allow_other --config-file=/mnt/batch/tasks/shared/LS_root/jobs/ss_my_aml/azureml/9fb10bab-4521-4cae-b106-9fa5fe30aae1/configs/workspaceblobstore.cfg --log-level=LOG_WARNING
# 2022-05-05T06:09:36Z Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/ss_my_aml/azureml/9fb10bab-4521-4cae-b106-9fa5fe30aae1/mounts/workspaceblobstore -- stdout/stderr:
# 2022-05-05T06:09:37Z The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2022-05-05T06:09:37Z Starting output-watcher...
# 2022-05-05T06:09:37Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_23e1bb4ca54a555eb02ea38dd537c165
# 92473f7ef455: Pulling fs layer
# fb52bde70123: Pulling fs layer
# 64788f86be3f: Pulling fs layer
# 33f6d5f2e001: Pulling fs layer
# eeb715f1b6ae: Pulling fs layer
# fe519cf36537: Pulling fs layer
# 58ff99196c15: Pulling fs layer
# 9b13f06a8eff: Pulling fs layer
# 2d4e93adbf58: Pulling fs layer
# 6ee7c3767844: Pulling fs layer
# 62cfc3ccb8ab: Pulling fs layer
# 4a7af9d757ee: Pulling fs layer
# 87befe721bae: Pulling fs layer
# 88ebf812112d: Pulling fs layer
# 6aec08a9bbdc: Pulling fs layer
# 7ab4917d9fd7: Pulling fs layer
# 0509d37259e1: Pulling fs layer
# a9fe999b238c: Pulling fs layer
# de332e6a4d0f: Pulling fs layer
# 948484c8c953: Pulling fs layer
# 69b601b6c28f: Pulling fs layer
# 576d2fdf95bc: Pulling fs layer
# 4a7af9d757ee: Waiting
# 87befe721bae: Waiting
# 88ebf812112d: Waiting
# 6aec08a9bbdc: Waiting
# 7ab4917d9fd7: Waiting
# 0509d37259e1: Waiting
# a9fe999b238c: Waiting
# de332e6a4d0f: Waiting
# 948484c8c953: Waiting
# 69b601b6c28f: Waiting
# 576d2fdf95bc: Waiting
# 33f6d5f2e001: Waiting
# eeb715f1b6ae: Waiting
# fe519cf36537: Waiting
# 58ff99196c15: Waiting
# 9b13f06a8eff: Waiting
# 2d4e93adbf58: Waiting
# 6ee7c3767844: Waiting
# fb52bde70123: Verifying Checksum
# fb52bde70123: Download complete
# 64788f86be3f: Verifying Checksum
# 64788f86be3f: Download complete
# 92473f7ef455: Verifying Checksum
# 92473f7ef455: Download complete
# 33f6d5f2e001: Verifying Checksum
# 33f6d5f2e001: Download complete
# fe519cf36537: Verifying Checksum
# fe519cf36537: Download complete
# 58ff99196c15: Verifying Checksum
# 58ff99196c15: Download complete
# eeb715f1b6ae: Verifying Checksum
# eeb715f1b6ae: Download complete
# 9b13f06a8eff: Verifying Checksum
# 9b13f06a8eff: Download complete
# 6ee7c3767844: Verifying Checksum
# 6ee7c3767844: Download complete
# 62cfc3ccb8ab: Verifying Checksum
# 62cfc3ccb8ab: Download complete
# 4a7af9d757ee: Verifying Checksum
# 4a7af9d757ee: Download complete
# 2d4e93adbf58: Verifying Checksum
# 2d4e93adbf58: Download complete
# 88ebf812112d: Verifying Checksum
# 88ebf812112d: Download complete
# 87befe721bae: Verifying Checksum
# 87befe721bae: Download complete
# 7ab4917d9fd7: Verifying Checksum
# 7ab4917d9fd7: Download complete
# 0509d37259e1: Verifying Checksum
# 0509d37259e1: Download complete
# a9fe999b238c: Verifying Checksum
# a9fe999b238c: Download complete
# de332e6a4d0f: Verifying Checksum
# de332e6a4d0f: Download complete
# 948484c8c953: Verifying Checksum
# 948484c8c953: Download complete
# 69b601b6c28f: Verifying Checksum
# 69b601b6c28f: Download complete
# 576d2fdf95bc: Verifying Checksum
# 576d2fdf95bc: Download complete
# 6aec08a9bbdc: Verifying Checksum
# 6aec08a9bbdc: Download complete
# 92473f7ef455: Pull complete
# fb52bde70123: Pull complete
# 64788f86be3f: Pull complete
# 33f6d5f2e001: Pull complete
# eeb715f1b6ae: Pull complete
# fe519cf36537: Pull complete
# 58ff99196c15: Pull complete
# 9b13f06a8eff: Pull complete
# 2d4e93adbf58: Pull complete
# 6ee7c3767844: Pull complete
# 62cfc3ccb8ab: Pull complete
# 4a7af9d757ee: Pull complete
# 87befe721bae: Pull complete
# 88ebf812112d: Pull complete
# 6aec08a9bbdc: Pull complete
# 7ab4917d9fd7: Pull complete
# 0509d37259e1: Pull complete
# a9fe999b238c: Pull complete
# de332e6a4d0f: Pull complete
# 948484c8c953: Pull complete
# 69b601b6c28f: Pull complete
# 576d2fdf95bc: Pull complete
# Digest: sha256:e0ff6a5a8b0ea8a124f6d75ed412c857758c55cbd3d9d109d61fd15290309d05
# Status: Downloaded newer image for viennaglobal.azurecr.io/azureml/azureml_23e1bb4ca54a555eb02ea38dd537c165:latest
# viennaglobal.azurecr.io/azureml/azureml_23e1bb4ca54a555eb02ea38dd537c165:latest
# 2022-05-05T06:10:08Z The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2022-05-05T06:10:08Z Check if container 9fb10bab-4521-4cae-b106-9fa5fe30aae1_DataSidecar already exist exited with 0,
#
# 47e38dbe80fa87aa38b7edfff61d1e1b8852c1e07d78090a1fadefd42602ac27
# 2022-05-05T06:10:09Z Parameters for containerSetup task: useDetonationChamer set to false and sshRequired set to false
# 2022-05-05T06:10:09Z containerSetup task cmd: [/mnt/batch/tasks/startup/wd/hosttools -task=containerSetup -traceContext=00-9c3a7532832b407f41402d80751a8cb5-069412dba1afc152-01 -sshRequired=false]
# 2022/05/05 06:10:09 Didn't get JobInfoJson from env, now read from file
# 2022/05/05 06:10:09 Suceeded read JobInfoJson from file
# 2022/05/05 06:10:09 Starting App Insight Logger for task:  containerSetup
# 2022/05/05 06:10:09 Version: 3.0.01936.0001 Branch: .SourceBranch Commit: 3b80c9b
# 2022/05/05 06:10:09 Entered ContainerSetupTask - Preparing infiniband
# 2022/05/05 06:10:09 Starting infiniband setup
# 2022/05/05 06:10:09 Python Version found is Python 3.7.9
#
# 2022/05/05 06:10:09 Returning Python Version as 3.7
# 2022-05-05T06:10:09Z VMSize: standard_ds11_v2, Host: runtime-gen1-ubuntu18, Container: ubuntu-16.04
# 2022/05/05 06:10:09 VMSize: standard_ds11_v2, Host: runtime-gen1-ubuntu18, Container: ubuntu-16.04
# 2022/05/05 06:10:09 VMSize: standard_ds11_v2, Host: runtime-gen1-ubuntu18, Container: ubuntu-16.04
# 2022/05/05 06:10:09 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2022/05/05 06:10:09 Not setting up Infiniband in Container
# 2022/05/05 06:10:09 Not setting up Infiniband in Container
# 2022-05-05T06:10:09Z Not setting up Infiniband in Container
# 2022/05/05 06:10:09 Python Version found is Python 3.7.9
#
# 2022/05/05 06:10:10 Returning Python Version as 3.7
# 2022/05/05 06:10:10 sshd inside container not required for job, skipping setup.
# 2022/05/05 06:10:10 All App Insights Logs was sent successfully or the close timeout of 10 was reached
# 2022/05/05 06:10:10 App Insight Client has already been closed
# 2022/05/05 06:10:10 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# Stopped: false
# OriginalData: 1
# FilteredData: 0.
# 2022-05-05T06:10:10Z Starting docker container succeeded.
# 2022-05-05T06:10:10Z The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
#
# Streaming azureml-logs/65_job_prep-tvmps_b9b383c961b9e9d38714d5ce559d014e3166b2fff5a40fbc49b91e43998007a4_d.txt
# ===============================================================================================================
# [2022-05-05T06:10:26.233430] Entering job preparation.
# [2022-05-05T06:10:27.363439] Starting job preparation.
# [2022-05-05T06:10:27.363487] Extracting the control code.
# [2022-05-05T06:10:27.364096] Starting extract_project.
# [2022-05-05T06:10:27.364140] Starting to extract zip file.
# [2022-05-05T06:10:27.382690] Finished extracting zip file.
# [2022-05-05T06:10:27.386315] Using urllib.request Python 3.0 or later
# [2022-05-05T06:10:27.386365] Start fetching snapshots.
# [2022-05-05T06:10:27.386403] Start fetching snapshot.
# Starting the daemon thread to refresh tokens in background for process with pid = 54
# [2022-05-05T06:10:27.681824] Finished fetching snapshot.
# [2022-05-05T06:10:27.681881] Start fetching snapshot.
# [2022-05-05T06:10:35.161715] Finished fetching snapshot.
# [2022-05-05T06:10:35.161764] Finished fetching snapshots.
# [2022-05-05T06:10:35.161788] Finished extract_project.
# [2022-05-05T06:10:35.161855] Finished fetching and extracting the control code.
# [2022-05-05T06:10:35.168462] Start run_history_prep.
# [2022-05-05T06:10:35.176455] Job preparation is complete.
# [2022-05-05T06:10:35.176762] Entering Data Context Managers in Sidecar
# [2022-05-05T06:10:35.177618] Running Sidecar prep cmd...
# Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.scriptrun = azureml.core.script_run:ScriptRun._from_run_dto with exception (cryptography 3.2.1 (/opt/miniconda/lib/python3.7/site-packages), Requirement.parse('cryptography>=3.3.1; extra == "crypto"'), {'PyJWT'}).
# [2022-05-05T06:10:35.610084] INFO azureml.sidecar.sidecar: Received task: enter_contexts. Running on Linux at /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/ss_my_aml/azureml/9fb10bab-4521-4cae-b106-9fa5fe30aae1/wd/azureml/9fb10bab-4521-4cae-b106-9fa5fe30aae1
# [2022-05-05T06:10:35.610934] INFO azureml.sidecar.sidecar: Invoking "enter_contexts" task with Context Managers: {"context_managers": ["Dataset:context_managers.Datasets"]}
#
# Streaming azureml-logs/65_job_prep-tvmps_03e8fd70f5a489120a451b3f271e284563569639c0d6e7acc5f801b7abce8bef_d.txt
# ===============================================================================================================
# [2022-05-05T06:10:12.646849] Entering job preparation.
# [2022-05-05T06:10:13.270584] Starting job preparation.
# [2022-05-05T06:10:13.270624] Extracting the control code.
# ...
# Script type = None
# [2022-05-05T06:11:33.542142] Entering Run History Context Manager.
# [2022-05-05T06:11:34.333335] Current directory: /mnt/batch/tasks/shared/LS_root/jobs/ss_my_aml/azureml/9fb10bab-4521-4cae-b106-9fa5fe30aae1/wd/azureml/9fb10bab-4521-4cae-b106-9fa5fe30aae1
# [2022-05-05T06:11:34.333587] Preparing to call script [driver/amlbi_main.py] with arguments:['--client_sdk_version', '1.40.0', '--scoring_module_name', 'batch_diabetes.py', '--mini_batch_size', '5', '--error_threshold', '10', '--output_action', 'append_row', '--logging_level', 'INFO', '--run_invocation_timeout', '60', '--run_max_try', '3', '--create_snapshot_at_runtime', 'True', '--output', '$inferences', '--input_fds_0', 'diabetes_batch']
# [2022-05-05T06:11:34.333615] After variable expansion, calling script [driver/amlbi_main.py] with arguments:['--client_sdk_version', '1.40.0', '--scoring_module_name', 'batch_diabetes.py', '--mini_batch_size', '5', '--error_threshold', '10', '--output_action', 'append_row', '--logging_level', 'INFO', '--run_invocation_timeout', '60', '--run_max_try', '3', '--create_snapshot_at_runtime', 'True', '--output', '/mnt/batch/tasks/shared/LS_root/jobs/ss_my_aml/azureml/9fb10bab-4521-4cae-b106-9fa5fe30aae1/wd/inferences_workspaceblobstore', '--input_fds_0', 'diabetes_batch']
#
# 2022/05/05 06:11:37 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# Stopped: false
# OriginalData: 1
# FilteredData: 0.
#
#
# [2022-05-05T06:12:37.173698] The experiment completed successfully. Finalizing run...
# Cleaning up all outstanding Run operations, waiting 900.0 seconds
# 3 items cleaning up...
#
# Streaming azureml-logs/75_job_post-tvmps_b9b383c961b9e9d38714d5ce559d014e3166b2fff5a40fbc49b91e43998007a4_d.txt
# ===============================================================================================================
# [2022-05-05T06:12:39.371729] Entering job release
# Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.scriptrun = azureml.core.script_run:ScriptRun._from_run_dto with exception (cryptography 3.2.1 (/opt/miniconda/lib/python3.7/site-packages), Requirement.parse('cryptography>=3.3.1; extra == "crypto"'), {'PyJWT'}).
# [2022-05-05T06:12:40.234575] Starting job release
# [2022-05-05T06:12:40.235183] Logging experiment finalizing status in history service.[2022-05-05T06:12:40.235393] job release stage : upload_datastore starting...
#
# Starting the daemon thread to refresh tokens in background for process with pid = 324
# [2022-05-05T06:12:40.236583] job release stage : start importing azureml.history._tracking in run_history_release.
# [2022-05-05T06:12:40.239598] job release stage : execute_job_release starting...
# [2022-05-05T06:12:40.239927] job release stage : copy_batchai_cached_logs starting...
# [2022-05-05T06:12:40.240662] job release stage : copy_batchai_cached_logs completed...
# [2022-05-05T06:12:40.251576] Entering context manager injector.
# [2022-05-05T06:12:40.257645] job release stage : upload_datastore completed...
# [2022-05-05T06:12:40.342377] job release stage : send_run_telemetry starting...
# [2022-05-05T06:12:40.392264] get vm size and vm region successfully.
# [2022-05-05T06:12:40.414444] get compute meta data successfully.
# [2022-05-05T06:12:40.564338] post artifact meta request successfully.
# [2022-05-05T06:12:40.601397] upload compute record artifact successfully.
# [2022-05-05T06:12:40.601529] job release stage : send_run_telemetry completed...
# [2022-05-05T06:12:41.113143] job release stage : execute_job_release completed...
# [2022-05-05T06:12:41.113678] Running in AzureML-Sidecar, starting to exit user context managers...
# [2022-05-05T06:12:41.113767] Running Sidecar release cmd...
# [2022-05-05T06:12:41.125129] INFO azureml.sidecar.sidecar: Received task: exit_contexts. Running on Linux at /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/ss_my_aml/azureml/9fb10bab-4521-4cae-b106-9fa5fe30aae1/wd/azureml/9fb10bab-4521-4cae-b106-9fa5fe30aae1
# [2022-05-05T06:12:41.143] Enter __exit__ of DatasetContextManager
# [2022-05-05T06:12:41.143] Unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/ss_my_aml/azureml/9fb10bab-4521-4cae-b106-9fa5fe30aae1/wd/diabetes_batch_c8916268-535f-461b-87a0-087fae85ab74.
# [2022-05-05T06:12:42.147] Finishing unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/ss_my_aml/azureml/9fb10bab-4521-4cae-b106-9fa5fe30aae1/wd/diabetes_batch_c8916268-535f-461b-87a0-087fae85ab74.
# [2022-05-05T06:12:42.147] Unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/ss_my_aml/azureml/9fb10bab-4521-4cae-b106-9fa5fe30aae1/wd/inferences_workspaceblobstore.
# fuse: failed to unmount /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/ss_my_aml/azureml/9fb10bab-4521-4cae-b106-9fa5fe30aae1/wd/inferences_workspaceblobstore: Invalid argument
# [2022-05-05T06:12:42.168] Finishing unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/ss_my_aml/azureml/9fb10bab-4521-4cae-b106-9fa5fe30aae1/wd/inferences_workspaceblobstore.
# [2022-05-05T06:12:42.168] Exit __exit__ of DatasetContextManager
# [2022-05-05T06:12:42.168387] Removing absolute paths from host...
# [2022-05-05T06:12:42.168803] INFO azureml.sidecar.task.exit_contexts: Exited Context Managers
# [2022-05-05T06:12:42.758644] Ran Sidecar release cmd.
# [2022-05-05T06:12:42.758912] Job release is complete
#
# Streaming azureml-logs/75_job_post-tvmps_03e8fd70f5a489120a451b3f271e284563569639c0d6e7acc5f801b7abce8bef_d.txt
# ===============================================================================================================
# [2022-05-05T06:12:39.992824] Entering job release
# Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.scriptrun = azureml.core.script_run:ScriptRun._from_run_dto with exception (cryptography 3.2.1 (/opt/miniconda/lib/python3.7/site-packages), Requirement.parse('cryptography>=3.3.1; extra == "crypto"'), {'PyJWT'}).
# [2022-05-05T06:12:40.889340] job release stage : copy_batchai_cached_logs starting...
# [2022-05-05T06:12:40.889390] job release stage : copy_batchai_cached_logs completed...
# [2022-05-05T06:12:40.889661] Running in AzureML-Sidecar, starting to exit user context managers...
# [2022-05-05T06:12:40.890550] Running Sidecar release cmd...
# [2022-05-05T06:12:40.900182] INFO azureml.sidecar.sidecar: Received task: exit_contexts. Running on Linux at /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/ss_my_aml/azureml/9fb10bab-4521-4cae-b106-9fa5fe30aae1/wd/azureml/9fb10bab-4521-4cae-b106-9fa5fe30aae1
# [2022-05-05T06:12:40.924] Enter __exit__ of DatasetContextManager
# [2022-05-05T06:12:40.924] Unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/ss_my_aml/azureml/9fb10bab-4521-4cae-b106-9fa5fe30aae1/wd/diabetes_batch_c8916268-535f-461b-87a0-087fae85ab74.
# [2022-05-05T06:12:41.927] Finishing unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/ss_my_aml/azureml/9fb10bab-4521-4cae-b106-9fa5fe30aae1/wd/diabetes_batch_c8916268-535f-461b-87a0-087fae85ab74.
# [2022-05-05T06:12:41.927] Unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/ss_my_aml/azureml/9fb10bab-4521-4cae-b106-9fa5fe30aae1/wd/inferences_workspaceblobstore.
# fuse: failed to unmount /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/ss_my_aml/azureml/9fb10bab-4521-4cae-b106-9fa5fe30aae1/wd/inferences_workspaceblobstore: Invalid argument
# [2022-05-05T06:12:41.952] Finishing unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/ss_my_aml/azureml/9fb10bab-4521-4cae-b106-9fa5fe30aae1/wd/inferences_workspaceblobstore.
# [2022-05-05T06:12:41.952] Exit __exit__ of DatasetContextManager
# [2022-05-05T06:12:41.952896] Removing absolute paths from host...
# [2022-05-05T06:12:41.953193] INFO azureml.sidecar.task.exit_contexts: Exited Context Managers
# [2022-05-05T06:12:42.498407] Ran Sidecar release cmd.
#
# StepRun(batch-score-diabetes) Execution Summary
# ================================================
# StepRun( batch-score-diabetes ) Status: Finished
# {'runId': '9fb10bab-4521-4cae-b106-9fa5fe30aae1', 'target': 'your-compute-cluster', 'status': 'Completed', 'startTimeUtc': '2022-05-05T06:09:31.758379Z', 'endTimeUtc': '2022-05-05T06:12:57.471484Z', 'services': {}, 'properties': {'ContentSnapshotId': '4bdf08c6-9865-4249-9194-8cd84a3f89b2', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': '7007b69a-8a94-45d4-bf48-54be8690d630', 'azureml.moduleName': 'batch-score-diabetes', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': '631217a5', 'azureml.pipelinerunid': '5cfa3dd1-4776-4a3d-b1a9-93020abeacb9', 'azureml.pipeline': '5cfa3dd1-4776-4a3d-b1a9-93020abeacb9', 'azureml.pipelineComponent': 'masterescloud', 'azureml.parallelrunstep': 'true', '_azureml.ComputeTargetType': 'amlctrain', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [{'dataset': {'id': 'c8916268-535f-461b-87a0-087fae85ab74'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'diabetes_batch', 'mechanism': 'Mount'}}], 'outputDatasets': [{'identifier': {'savedId': 'a9faa7ea-288e-4717-9c01-677e42fb75c9'}, 'outputType': 'RunOutput', 'outputDetails': {'outputName': 'inferences'}, 'dataset': {
#   "source": [
#     "('workspaceblobstore', 'dataset/9fb10bab-4521-4cae-b106-9fa5fe30aae1/inferences/')"
#   ],
#   "definition": [
#     "GetDatastoreFiles"
#   ],
#   "registration": {
#     "id": "a9faa7ea-288e-4717-9c01-677e42fb75c9",
#     "name": null,
#     "version": null,
#     "workspace": "Workspace.create(name='ss_my_aml', subscription_id='1e17398b-590b-4bc5-b425-d1e505573710', resource_group='ss_my_resgrp')"
#   }
# }}], 'runDefinition': {'script': 'driver/amlbi_main.py', 'command': '', 'useAbsolutePath': False, 'arguments': ['--client_sdk_version', '1.40.0', '--scoring_module_name', 'batch_diabetes.py', '--mini_batch_size', '5', '--error_threshold', '10', '--output_action', 'append_row', '--logging_level', 'INFO', '--run_invocation_timeout', '60', '--run_max_try', '3', '--create_snapshot_at_runtime', 'True', '--output', 'DatasetOutputConfig:inferences', '--input_fds_0', 'diabetes_batch'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'your-compute-cluster', 'dataReferences': {}, 'data': {'diabetes_batch': {'dataLocation': {'dataset': {'id': 'c8916268-535f-461b-87a0-087fae85ab74', 'name': None, 'version': '1'}, 'dataPath': None, 'uri': None, 'type': None}, 'mechanism': 'Mount', 'environmentVariableName': 'diabetes_batch', 'pathOnCompute': None, 'overwrite': False, 'options': None}}, 'outputData': {'inferences': {'outputLocation': {'dataset': None, 'dataPath': {'datastoreName': 'workspaceblobstore', 'relativePath': None}, 'uri': None, 'type': None}, 'mechanism': 'Mount', 'additionalOptions': {'pathOnCompute': None, 'registrationOptions': {'name': None, 'description': None, 'tags': None, 'properties': {'azureml.pipelineRunId': '5cfa3dd1-4776-4a3d-b1a9-93020abeacb9', 'azureml.pipelineRun.moduleNodeId': '631217a5', 'azureml.pipelineRun.outputPortName': 'inferences'}, 'datasetRegistrationOptions': {'additionalTransformation': None}}, 'uploadOptions': {'overwrite': False, 'sourceGlobs': {'globPatterns': None}}, 'mountOptions': None}, 'environmentVariableName': None}}, 'datacaches': [], 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 2, 'instanceTypes': [], 'priority': None, 'credentialPassthrough': False, 'identity': None, 'environment': {'name': 'experiment_env', 'version': 'Autosave_2022-05-05T05:58:07Z_e800239b', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'name': 'batch_environment', 'dependencies': ['python=3.6.2', 'scikit-learn', 'pip', {'pip': ['azureml-defaults']}]}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20220314.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': False, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': 'D2', 'imageVersion': 'pytorch-1.7.0', 'location': None, 'aiSuperComputerStorageData': None, 'interactive': False, 'scalePolicy': None, 'virtualClusterArmId': None, 'tensorboardLogDirectory': None, 'sshPublicKey': None, 'sshPublicKeys': None, 'enableAzmlInt': True, 'priority': 'Medium', 'slaTier': 'Standard', 'userAlias': None}, 'kubernetesCompute': {'instanceType': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'pyTorch': {'communicationBackend': 'nccl', 'processCount': None}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': True, 'sharedVolumes': True, 'shmSize': '2g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}, 'commandReturnCodeConfig': {'returnCode': 'Zero', 'successfulReturnCodes': []}, 'environmentVariables': {}, 'applicationEndpoints': {}, 'pa ...
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '5cfa3dd1-4776-4a3d-b1a9-93020abeacb9', 'status': 'Completed', 'startTimeUtc': '2022-05-05T05:57:12.114944Z', 'endTimeUtc': '2022-05-05T06:12:59.268051Z', 'services': {}, 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}', 'azureml.continue_on_step_failure': 'False', 'azureml.pipelineComponent': 'pipelinerun'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://ssmyaml1022859275.blob.core.windows.net/azureml/ExperimentRun/dcid.5cfa3dd1-4776-4a3d-b1a9-93020abeacb9/logs/azureml/executionlogs.txt?sv=2019-07-07&sr=b&sig=%2F9qGfAf0RIqQE6FrZO6%2Br0X%2BFY73tyEhII4XO%2B2Eprk%3D&skoid=59eeec55-b923-47a2-befc-ad672ccc0882&sktid=ae991c30-8b25-49cb-99eb-82160b7acac2&skt=2022-05-05T05%3A46%3A32Z&ske=2022-05-06T13%3A56%3A32Z&sks=b&skv=2019-07-07&st=2022-05-05T06%3A03%3A01Z&se=2022-05-05T14%3A13%3A01Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://ssmyaml1022859275.blob.core.windows.net/azureml/ExperimentRun/dcid.5cfa3dd1-4776-4a3d-b1a9-93020abeacb9/logs/azureml/stderrlogs.txt?sv=2019-07-07&sr=b&sig=gDD%2FFNhO7Lsp8s6gUMgsnNJ6teeuHlVH%2BL1MjG6M3fc%3D&skoid=59eeec55-b923-47a2-befc-ad672ccc0882&sktid=ae991c30-8b25-49cb-99eb-82160b7acac2&skt=2022-05-05T05%3A46%3A32Z&ske=2022-05-06T13%3A56%3A32Z&sks=b&skv=2019-07-07&st=2022-05-05T06%3A03%3A01Z&se=2022-05-05T14%3A13%3A01Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://ssmyaml1022859275.blob.core.windows.net/azureml/ExperimentRun/dcid.5cfa3dd1-4776-4a3d-b1a9-93020abeacb9/logs/azureml/stdoutlogs.txt?sv=2019-07-07&sr=b&sig=b9oujvVxXJjtV3R5Hl1ajRYpXZHUpFh0n%2BECcVdCV5k%3D&skoid=59eeec55-b923-47a2-befc-ad672ccc0882&sktid=ae991c30-8b25-49cb-99eb-82160b7acac2&skt=2022-05-05T05%3A46%3A32Z&ske=2022-05-06T13%3A56%3A32Z&sks=b&skv=2019-07-07&st=2022-05-05T06%3A03%3A01Z&se=2022-05-05T14%3A13%3A01Z&sp=r'}, 'submittedBy': 'shivani singhal'}
# 'Finished'

# %% [markdown]
# When the pipeline has finished running, the resulting predictions will have been saved in the outputs of the experiment associated with the first (and only) step in the pipeline. You can retrieve it as follows:

# %%
import pandas as pd
import shutil

# Remove the local results folder if left over from a previous run
shutil.rmtree('diabetes-results', ignore_errors=True)

# Get the run for the first step and download its output
prediction_run = next(pipeline_run.get_children())
prediction_output = prediction_run.get_output_data('inferences')
prediction_output.download(local_path='diabetes-results')

# Traverse the folder hierarchy and find the results file
for root, dirs, files in os.walk('diabetes-results'):
    for file in files:
        if file.endswith('parallel_run_step.txt'):
            result_file = os.path.join(root,file)

# cleanup output format
df = pd.read_csv(result_file, delimiter=":", header=None)
df.columns = ["File", "Prediction"]

# Display the first 20 results
df.head(20)
# Out:
#        File  Prediction
# 0     1.csv           1
# 1    10.csv           0
# 2   100.csv           0
# 3    11.csv           1
# 4    12.csv           1
# 5    13.csv           1
# 6    14.csv           1
# 7    15.csv           0
# 8    16.csv           0
# 9    17.csv           1
# 10   18.csv           0
# 11   19.csv           0
# 12    2.csv           1
# 13   20.csv           1
# 14   21.csv           0
# 15   22.csv           1
# 16   23.csv           1
# 17   24.csv           1
# 18   25.csv           0
# 19   26.csv           0

# %% [markdown]
# ## Publish the Pipeline and use its REST Interface
#
# Now that you have a working pipeline for batch inferencing, you can publish it and use a REST endpoint to run it from an application.

# %%
published_pipeline = pipeline_run.publish_pipeline(
    name='diabetes-batch-pipeline', description='Batch scoring of diabetes data', version='1.0')

published_pipeline
# Out:
# Pipeline(Name: diabetes-batch-pipeline,
# Id: 2803e0a4-7b17-40eb-9850-ec8858c3023b,
# Status: Active,
# Endpoint: https://australiaeast.api.azureml.ms/pipelines/v1.0/subscriptions/1e17398b-590b-4bc5-b425-d1e505573710/resourceGroups/ss_my_resgrp/providers/Microsoft.MachineLearningServices/workspaces/ss_my_aml/PipelineRuns/PipelineSubmit/2803e0a4-7b17-40eb-9850-ec8858c3023b)

# %% [markdown]
# Note that the published pipeline has an endpoint, which you can see in the Azure portal. You can also find it as a property of the published pipeline object:

# %%
rest_endpoint = published_pipeline.endpoint
print(rest_endpoint)
# Out:
# https://australiaeast.api.azureml.ms/pipelines/v1.0/subscriptions/1e17398b-590b-4bc5-b425-d1e505573710/resourceGroups/ss_my_resgrp/providers/Microsoft.MachineLearningServices/workspaces/ss_my_aml/PipelineRuns/PipelineSubmit/2803e0a4-7b17-40eb-9850-ec8858c3023b

# %% [markdown]
# To use the endpoint, client applications need to make a REST call over HTTP. This request must be authenticated, so an authorization header is required. To test this out, we'll use the authorization header from your current connection to your Azure workspace, which you can get using the following code:
#
# > **Note**: A real application would require a service principal with which to be authenticated.

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()
print('Authentication header ready.')
# Out:
# Authentication header ready.

# %% [markdown]
# Now we're ready to call the REST interface. The pipeline runs asynchronously, so we'll get an identifier back, which we can use to track the pipeline experiment as it runs:

# %%
import requests

rest_endpoint = published_pipeline.endpoint
response = requests.post(rest_endpoint, 
                         headers=auth_header, 
                         json={"ExperimentName": "mslearn-diabetes-batch"})
run_id = response.json()["Id"]
run_id
# Out:
# 'be6c5541-93b0-47bd-83bc-73f12352bdf0'

# %% [markdown]
# Since we have the run ID, we can use the **RunDetails** widget to view the experiment as it runs:

# %%
from azureml.pipeline.core.run import PipelineRun
from azureml.widgets import RunDetails

published_pipeline_run = PipelineRun(ws.experiments['mslearn-diabetes-batch'], run_id)

# Block until the run completes
published_pipeline_run.wait_for_completion(show_output=True)
# Out:
# PipelineRunId: be6c5541-93b0-47bd-83bc-73f12352bdf0
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/be6c5541-93b0-47bd-83bc-73f12352bdf0?wsid=/subscriptions/1e17398b-590b-4bc5-b425-d1e505573710/resourcegroups/ss_my_resgrp/workspaces/ss_my_aml&tid=ae991c30-8b25-49cb-99eb-82160b7acac2
# PipelineRun Status: NotStarted
# PipelineRun Status: Running
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': 'be6c5541-93b0-47bd-83bc-73f12352bdf0', 'status': 'Completed', 'startTimeUtc': '2022-05-05T06:13:09.584635Z', 'endTimeUtc': '2022-05-05T06:13:10.594129Z', 'services': {}, 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'Unavailable', 'runType': 'HTTP', 'azureml.parameters': '{}', 'azureml.continue_on_step_failure': 'False', 'azureml.pipelineid': '2803e0a4-7b17-40eb-9850-ec8858c3023b', 'azureml.pipelineComponent': 'pipelinerun'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://ssmyaml1022859275.blob.core.windows.net/azureml/ExperimentRun/dcid.be6c5541-93b0-47bd-83bc-73f12352bdf0/logs/azureml/executionlogs.txt?sv=2019-07-07&sr=b&sig=4eB4y2edYqTssBjqvl4sSopApEnZ0iuj7lQKwwoFgCg%3D&skoid=59eeec55-b923-47a2-befc-ad672ccc0882&sktid=ae991c30-8b25-49cb-99eb-82160b7acac2&skt=2022-05-05T05%3A46%3A32Z&ske=2022-05-06T13%3A56%3A32Z&sks=b&skv=2019-07-07&st=2022-05-05T06%3A03%3A11Z&se=2022-05-05T14%3A13%3A11Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://ssmyaml1022859275.blob.core.windows.net/azureml/ExperimentRun/dcid.be6c5541-93b0-47bd-83bc-73f12352bdf0/logs/azureml/stderrlogs.txt?sv=2019-07-07&sr=b&sig=Z%2FV2LTwu1U%2BhSO89VttlDZnoBinfIyt2dde%2FXXrIAqY%3D&skoid=59eeec55-b923-47a2-befc-ad672ccc0882&sktid=ae991c30-8b25-49cb-99eb-82160b7acac2&skt=2022-05-05T05%3A46%3A32Z&ske=2022-05-06T13%3A56%3A32Z&sks=b&skv=2019-07-07&st=2022-05-05T06%3A03%3A11Z&se=2022-05-05T14%3A13%3A11Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://ssmyaml1022859275.blob.core.windows.net/azureml/ExperimentRun/dcid.be6c5541-93b0-47bd-83bc-73f12352bdf0/logs/azureml/stdoutlogs.txt?sv=2019-07-07&sr=b&sig=vSdIMPnrhDbU%2FxtPweDFLVIH%2BZgsDPmb0T4Gw4q8xB0%3D&skoid=59eeec55-b923-47a2-befc-ad672ccc0882&sktid=ae991c30-8b25-49cb-99eb-82160b7acac2&skt=2022-05-05T05%3A46%3A32Z&ske=2022-05-06T13%3A56%3A32Z&sks=b&skv=2019-07-07&st=2022-05-05T06%3A03%3A11Z&se=2022-05-05T14%3A13%3A11Z&sp=r'}, 'submittedBy': 'shivani singhal'}
# 'Finished'

# %% [markdown]
# Wait for the pipeline run to complete, and then run the following cell to see the results.
#
# As before, the results are in the output of the first pipeline step:

# %%
import pandas as pd
import shutil

# Remove the local results folder if left over from a previous run
shutil.rmtree('diabetes-results', ignore_errors=True)

# Get the run for the first step and download its output
prediction_run = next(pipeline_run.get_children())
prediction_output = prediction_run.get_output_data('inferences')
prediction_output.download(local_path='diabetes-results')

# Traverse the folder hierarchy and find the results file
for root, dirs, files in os.walk('diabetes-results'):
    for file in files:
        if file.endswith('parallel_run_step.txt'):
            result_file = os.path.join(root,file)

# cleanup output format
df = pd.read_csv(result_file, delimiter=":", header=None)
df.columns = ["File", "Prediction"]

# Display the first 20 results
df.head(20)
# Out:
#        File  Prediction
# 0     1.csv           1
# 1    10.csv           0
# 2   100.csv           0
# 3    11.csv           1
# 4    12.csv           1
# 5    13.csv           1
# 6    14.csv           1
# 7    15.csv           0
# 8    16.csv           0
# 9    17.csv           1
# 10   18.csv           0
# 11   19.csv           0
# 12    2.csv           1
# 13   20.csv           1
# 14   21.csv           0
# 15   22.csv           1
# 16   23.csv           1
# 17   24.csv           1
# 18   25.csv           0
# 19   26.csv           0

# %% [markdown]
# Now you have a pipeline that can be used to batch process daily patient data.
#
# **More Information**: For more details about using pipelines for batch inferencing, see the [How to Run Batch Predictions](https://docs.microsoft.com/azure/machine-learning/how-to-run-batch-predictions) in the Azure Machine Learning documentation.
